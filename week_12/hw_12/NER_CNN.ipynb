# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('./path/news2.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 188

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('The', 'DT'),
#  ('rise', 'NN'),
#  ('and', 'CC'),
#  ('fall', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('Belt', 'NNP'),
#  ('and', 'CC'),
#  ('Road', 'NNP'),
#  ('billionaire', 'NN'),
#  ('By', 'IN'),
#  ('Jenni', 'NNP'),
#  ('Marsh', 'NNP'),
#  (',', ','),
#  ('CNN', 'NNP'),
#  ('Photo', 'NNP'),
#  ('illustration/AP', 'NN'),
#  ('Images', 'NNP'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('mid-1990s', 'NNS'),
#  (',', ','),
#  ('Ye', 'NNP'),
#  ('Jianming', 'NNP'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('simple', 'JJ'),
#  ('job', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('forest', 'NN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('so', 'RB'),
#  ('his', 'PRP$'),
#  ('story', 'NN'),
#  ('goes', 'VBZ'),
#  ('.', '.'),
#  ('Twenty', 'CD'),
#  ('years', 'NNS'),
#  ('later', 'RB'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('sat', 'VBD'),
#  ('atop', 'VB'),
#  ('a', 'DT'),
#  ('$', '$'),
#  ('44', 'CD'),
#  ('billion', 'CD'),
#  ('business', 'NN'),
#  ('empire', 'NN'),
#  ('.', '.'),
#  ('Today', 'NN'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('has', 'VBZ'),
#  ('vanished', 'VBN'),
#  ('and', 'CC'),
#  (',', ','),
#  ('as', 'IN'),
#  ('that', 'DT'),
#  ('empire', 'NN'),
#  ('crumbles', 'NNS'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('reportedly', 'RB'),
#  ('under', 'IN'),
#  ('investigation', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('government', 'NN'),
#  ('.', '.'),
#  ('How', 'WRB'),
#  ('all', 'DT'),
#  ('that', 'DT'),
#  ('happened', 'VBD'),
#  ('remains', 'VBZ'),
#  ('largely', 'RB'),
#  ('unknown', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('one', 'CD'),
#  ('thing', 'NN'),
#  ('is', 'VBZ'),
#  ('clear', 'JJ'),
#  (':', ':'),
#  ('at', 'IN'),
#  ('its', 'PRP$'),
#  ('height', 'NN'),
#  (',', ','),
#  ('Ye', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('company', 'NN'),
#  (',', ','),
#  ('CEFC', 'NNP'),
#  ('China', 'NNP'),
#  ('Energy', 'NNP'),
#  (',', ','),
#  ('aligned', 'VBD'),
#  ('itself', 'PRP'),
#  ('so', 'RB'),
#  ('closely', 'RB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('government', 'NN'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('often', 'RB'),
#  ('hard', 'JJ'),
#  ('to', 'TO'),
#  ('distinguish', 'VB'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('young', 'JJ'),
#  ('tycoon', 'NN'),
#  ('appeared', 'VBD'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('unofficial', 'JJ'),
#  ('energy', 'NN'),
#  ('envoy', 'NN'),
#  (',', ','),
#  ('meeting', 'NN'),
#  ('presidents', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('globe', 'NN'),
#  ('and', 'CC'),
#  ('even', 'RB'),
#  ('becoming', 'VBG'),
#  ('an', 'DT'),
#  ('adviser', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('European', 'JJ'),
#  ('government', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('ranked', 'VBD'),
#  ('No', 'NNP'),
#  ('.', '.'),
#  ('2', 'CD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Fortune', 'NNP'),
#  ('magazine', 'NN'),
#  ('40', 'CD'),
#  ('Under', 'IN'),
#  ('40', 'CD'),
#  ('list', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('last', 'JJ'),
#  ('November', 'NNP'),
#  (',', ','),
#  ('Ye', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('seemingly', 'RB'),
#  ('unstoppable', 'JJ'),
#  ('rise', 'NN'),
#  ('came', 'VBD'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('screeching', 'JJ'),
#  ('halt', 'NN'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('undoing', 'NN'),
#  ('came', 'VBD'),
#  ('after', 'IN'),
#  ('US', 'NNP'),
#  ('prosecutors', 'NNS'),
#  ('alleged', 'VBD'),
#  ('that', 'IN'),
#  ('an', 'DT'),
#  ('NGO', 'NNP'),
#  ('he', 'PRP'),
#  ('funded', 'VBD'),
#  ('had', 'VBD'),
#  ('used', 'VBN'),
#  ('its', 'PRP$'),
#  ('United', 'NNP'),
#  ('Nations', 'NNPS'),
#  ('status', 'NN'),
#  ('to', 'TO'),
#  ('offer', 'VB'),
#  ('millions', 'NNS'),
#  ('in', 'IN'),
#  ('bribes', 'NN'),
#  ('to', 'TO'),
#  ('African', 'JJ'),
#  ('leaders', 'NNS'),
#  (',', ','),
#  ('although', 'IN'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('charged', 'VBN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('that', 'DT'),
#  ('case', 'NN'),
#  ('plays', 'VBZ'),
#  ('out', 'RP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('Manhattan', 'NNP'),
#  ('courthouse', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('is', 'VBZ'),
#  ('offered', 'VBN'),
#  ('a', 'DT'),
#  ('rare', 'JJ'),
#  ('glimpse', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('complex', 'JJ'),
#  ('relations', 'NNS'),
#  ('between', 'IN'),
#  ('private', 'JJ'),
#  ('business', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('state', 'NN'),
#  ('--', ':'),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('cautionary', 'JJ'),
#  ('tale', 'NN'),
#  ('of', 'IN'),
#  ('what', 'WP'),
#  ('happens', 'VBZ'),
#  ('when', 'WRB'),
#  ('a', 'DT'),
#  ('Chinese', 'JJ'),
#  ('company', 'NN'),
#  ('fails', 'VBZ'),
#  ('abroad', 'RB'),
#  ('.', '.'),
#  ('Czech', 'JJ'),
#  ('invasion', 'NN'),
#  ('Ye', 'NNP'),
#  ('came', 'VBD'),
#  ('to', 'TO'),
#  ('international', 'JJ'),
#  ('prominence', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('summer', 'NN'),
#  ('of', 'IN'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('an', 'DT'),
#  ('extraordinary', 'JJ'),
#  ('buying', 'NN'),
#  ('spree', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('the', 'DT'),
#  ('chairman', 'NN'),
#  ('of', 'IN'),
#  ('CEFC', 'NNP'),
#  ('China', 'NNP'),
#  ('Energy', 'NNP'),
#  (',', ','),
#  ('Ye', 'NNP'),
#  ('snapped', 'VBD'),
#  ('up', 'RP'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('oldest', 'JJS'),
#  ('football', 'NN'),
#  ('club', 'NN'),
#  (',', ','),
#  ('Slavia', 'NNP'),
#  ('Praha', 'NNP'),
#  (';', ':'),
#  ('a', 'DT'),
#  ('brewery', 'NN'),
#  (';', ':'),
#  ('a', 'DT'),
#  ('share', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Travel', 'NNP'),
#  ('Service', 'NNP'),
#  ('airline', 'NN'),
#  ('group', 'NN'),
#  (';', ':'),
#  ('a', 'DT'),
#  ('publishing', 'NN'),
#  ('house', 'NN'),
#  (';', ':'),
#  ('a', 'DT'),
#  ('neo-renaissance', 'JJ'),
#  ('building', 'NN'),
#  (';', ':'),
#  ('a', 'DT'),
#  ('stake', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('investment', 'NN'),
#  ('bank', 'NN'),
#  ('J', 'NNP'),
#  ('&', 'CC'),
#  ('T', 'NNP'),
#  ('Finance', 'NNP'),
#  ('Group', 'NNP'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('building', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('capital', 'NN'),
#  ('Prague', 'NNP'),
#  (',', ','),
#  ('intended', 'VBD'),
#  ('for', 'IN'),
#  ('use', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ("'s", 'POS'),
#  ('European', 'JJ'),
#  ('headquarters', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('CEFC', 'NNP'),
#  ('China', 'NNP'),
#  ('Energy', 'NNP'),
#  ('sign', 'NN'),
#  ('in', 'IN'),
#  ('Shanghai', 'NNP'),
#  (',', ','),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('Newscom', 'NNP'),
#  ('Inside', 'IN'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('acquisitions', 'NNS'),
#  ('were', 'VBD'),
#  ('greeted', 'VBN'),
#  ('with', 'IN'),
#  ('bemusement', 'NN'),
#  (':', ':'),
#  ('Why', 'WRB'),
#  ('would', 'MD'),
#  ('an', 'DT'),
#  ('energy', 'NN'),
#  ('company', 'NN'),
#  ('want', 'VBP'),
#  ('a', 'DT'),
#  ('brewery', 'NN'),
#  ('?', '.'),
#  ('And', 'CC'),
#  ('why', 'WRB'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('Chinese', 'JJ'),
#  ('company', 'NN'),
#  ('suddenly', 'RB'),
#  ('so', 'RB'),
#  ('welcome', 'JJ'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('that', 'WDT'),
#  ('had', 'VBD'),
#  (',', ','),
#  ('until', 'IN'),
#  ('recently', 'RB'),
#  (',', ','),
#  ('been', 'VBN'),
#  ('hostile', 'JJ'),
#  ('to', 'TO'),
#  ('China', 'NNP'),
#  ('?', '.'),
#  ('As', 'IN'),
#  ('with', 'IN'),
#  ('just', 'RB'),
#  ('about', 'IN'),
#  ('everything', 'NN'),
#  ('involving', 'VBG'),
#  ('CEFC', 'NNP'),
#  ('China', 'NNP'),
#  ('Energy', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('answers', 'NNS'),
#  ('would', 'MD'),
#  ('eventually', 'RB'),
#  ('point', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('government', 'NN'),
#  ('.', '.'),
#  ('From', 'IN'),
#  ('its', 'PRP$'),
#  ('founding', 'NN'),
#  ('in', 'IN'),
#  ('1993', 'CD'),
#  ('until', 'IN'),
#  ('2003', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  ('was', 'VBD'),
#  ('led', 'VBN'),
#  ('by', 'IN'),
#  ('Vaclav', 'NNP'),
#  ('Havel', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('dissident', 'NN'),
#  ('turned', 'VBD'),
#  ('elected', 'JJ'),
#  ('politician', 'NN'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('impassioned', 'JJ'),
#  ('campaigning', 'NN'),
#  ('had', 'VBD'),
#  ('helped', 'VBN'),
#  ('topple', 'VB'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('former', 'JJ'),
#  ('communist', 'JJ'),
#  ('government', 'NN'),
#  ('and', 'CC'),
#  ('usher', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('era', 'NN'),
#  ('of', 'IN'),
#  ('democracy', 'NN'),
#  ('.', '.'),
#  ('Throughout', 'IN'),
#  ('his', 'PRP$'),
#  ('decade', 'NN'),
#  ('in', 'IN'),
#  ('office', 'NN'),
#  (',', ','),
#  ('Havel', 'NNP'),
#  ('made', 'VBD'),
#  ('no', 'DT'),
#  ('attempt', 'NN'),
#  ('to', 'TO'),
#  ('hide', 'VB'),
#  ('his', 'PRP$'),
#  ('disdain', 'NN'),
#  ('for', 'IN'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('own', 'JJ'),
#  ('communist', 'NN'),
#  ('rulers', 'NNS'),
#  (',', ','),
#  ('regularly', 'RB'),
#  ('meeting', 'VBG'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Dalai', 'NNP'),
#  ('Lama', 'NNP'),
#  ('--', ':'),
#  ('who', 'WP'),
#  ('is', 'VBZ'),
#  ('considered', 'VBN'),
#  ('by', 'IN'),
#  ('China', 'NNP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('dangerous', 'JJ'),
#  ('separatist', 'NN'),
#  ('.', '.'),
#  ('Relations', 'NNS'),
#  ('changed', 'VBD'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  ('of', 'IN'),
#  ('Milos', 'NNP'),
#  ('Zeman', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('top', 'JJ'),
#  ('office', 'NN'),
#  ('in', 'IN'),
#  ('2013', 'CD'),
#  ('.', '.'),
#  ('Touted', 'VBN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('China-friendly', 'JJ'),
#  ('president', 'NN'),
#  (',', ','),
#  ('Zeman', 'NNP'),
#  ('was', 'VBD'),
#  ('keen', 'JJ'),
#  ('to', 'TO'),
#  ('facilitate', 'VB'),
#  ('increased', 'VBN'),
#  ('trade', 'NN'),
#  ('between', 'IN'),
#  ('Beijing', 'NNP'),
#  ('and', 'CC'),
#  ('Prague', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('following', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Czech', 'JJ'),
#  ('entity', 'NN'),
#  ('would', 'MD'),
#  ('become', 'VB'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('wholly', 'RB'),
#  ('foreign-owned', 'JJ'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('provide', 'VB'),
#  ('loans', 'NNS'),
#  ('across', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('huge', 'JJ'),
#  ('coup', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('relatively', 'RB'),
#  ('untapped', 'JJ'),
#  ('consumer', 'NN'),
#  ('credit', 'NN'),
#  ('market', 'NN'),
#  ('.', '.'),
#  ('Ye', 'NNP'),
#  ('sensed', 'VBD'),
#  ('an', 'DT'),
#  ('opportunity', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('was', 'VBD'),
#  ('quietly', 'RB'),
#  ('made', 'VBN'),
#  ('a', 'DT'),
#  ('special', 'JJ'),
#  ('economic', 'JJ'),
#  ('adviser', 'NN'),
#  ('to', 'TO'),
#  ('Zeman', 'NNP'),
#  (',', ','),
#  ('something', 'NN'),
#  ('that', 'WDT'),
#  ('would', 'MD'),
#  ('only', 'RB'),
#  ('be', 'VB'),
#  ('announced', 'VBN'),
#  ('six', 'CD'),
#  ('months', 'NNS'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('.', '.'),
#  ('Miroslav', 'NNP'),
#  ('Kalousek', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Czech', 'JJ'),
#  ('opposition', 'NN'),
#  ('MP', 'NNP'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('he', 'PRP'),
#  ('considers', 'VBZ'),
#  ('Ye', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('country', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('government', 'NN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('scandalous', 'JJ'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('security', 'NN'),
#  ('risk', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Shortly', 'RB'),
#  ('after', 'IN'),
#  ('Ye', 'NNP'),
#  ("'s", 'POS'),
#  ('appointment', 'NN'),
#  ('came', 'VBD'),
#  ('his', 'PRP$'),
#  ('high-profile', 'JJ'),
#  ('splurge', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('deals', 'NNS'),
#  ('made', 'VBD'),
#  ('no', 'DT'),
#  ('commercial', 'JJ'),
#  ('sense', 'NN'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('Martin', 'NNP'),
#  ('Hala', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('leading', 'VBG'),
#  ('Czech', 'JJ'),
#  ('academic', 'JJ'),
#  ('in', 'IN'),
#  ('Chinese', 'JJ'),
#  ('studies', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('they', 'PRP'),
#  ('sent', 'VBD'),
#  ('a', 'DT'),
#  ('clear', 'JJ'),
#  ('message', 'NN'),
#  ('from', 'IN'),
#  ('Beijing', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('international', 'JJ'),
#  ('community', 'NN'),
#  ('that', 'IN'),
#  ('China', 'NNP'),
#  ('now', 'RB'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('firm', 'JJ'),
#  ('friend', 'NN'),
#  ('in', 'IN'),
#  ('Europe', 'NNP'),
#  ('.', '.'),
#  ('That', 'DT'),
#  ('was', 'VBD'),
#  ('important', 'JJ'),
#  ('.', '.'),
#  ('Chinese', 'JJ'),
#  ('President', 'NNP'),
#  ('Xi', 'NNP'),
#  ('Jinping', 'NNP'),
#  ("'s", 'POS'),
#  ('flagship', 'NN'),
#  ('Belt', 'NNP'),
#  ('and', 'CC'),
#  ('Road', 'NNP'),
#  ('initiative', 'NN'),
#  ('aims', 'NNS'),
#  ('to', 'TO'),
#  ('export', 'VB'),
#  ('Chinese', 'NNP'),
#  ('commerce', 'NN'),
#  (',', ','),
#  ('goods', 'NNS'),
#  ('and', 'CC'),
#  ('influence', 'NN'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('globe', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('foothold', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  ('gave', 'VBD'),
#  ('China', 'NNP'),
#  ('a', 'DT'),
#  ('gateway', 'NN'),
#  ('to', 'TO'),
#  ('Europe', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('valuable', 'JJ'),
#  ('political', 'JJ'),
#  ('ally', 'NN'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  (',', ','),
#  ('Beijing', 'NNP'),
#  ("'s", 'POS'),
#  ('largest', 'JJS'),
#  ('trading', 'NN'),
#  ('partner', 'NN'),
#  ('.', '.'),
#  ('Chinese', 'JJ'),
#  ('President', 'NNP'),
#  ('Xi', 'NNP'),
#  ('Jinping', 'NNP'),
#  (',', ','),
#  ('second', 'NN'),
#  ('from', 'IN'),
#  ('right', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('Czech', 'NNP'),
#  ('President', 'NNP'),
#  ('Milos', 'NNP'),
#  ('Zeman', 'NNP'),
#  (',', ','),
#  ('third', 'JJ'),
#  ('from', 'IN'),
#  ('left', 'NN'),
#  (',', ','),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Great', 'NNP'),
#  ('Hall', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('People', 'NNP'),
#  ('in', 'IN'),
#  ('Beijing', 'NNP'),
#  ('in', 'IN'),
#  ('September', 'NNP'),
#  (',', ','),
#  ('2015', 'CD'),
#  ('.', '.'),
#  ('Ye', 'VB'),
#  ('Jianming', 'NNP'),
#  ('is', 'VBZ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('far', 'RB'),
#  ('left', 'NN'),
#  ('.', '.'),
#  ('Lucie', 'NNP'),
#  ('Mikolaskova', 'NNP'),
#  ('(', '('),
#  ('CTK', 'NNP'),
#  ('via', 'IN'),
#  ('AP', 'NNP'),
#  ('Images', 'NNP'),
#  (')', ')'),
#  ('Stephen', 'NNP'),
#  ('Platt', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('historian', 'NN'),
#  ('and', 'CC'),
#  ('professor', 'NN'),
#  ('of', 'IN'),
#  ('Chinese', 'JJ'),
#  ('history', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('Massachusetts', 'NNP'),
#  ('Amherst', 'NNP'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('history', 'NN'),
#  ('of', 'IN'),
#  ('private', 'JJ'),
#  ('businessmen', 'NNS'),
#  ('advancing', 'VBG'),
#  ('the', 'DT'),
#  ('influence', 'NN'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('country', 'NN'),
#  ('abroad', 'RB'),
#  (',', ','),
#  ('dating', 'VBG'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('British', 'JJ'),
#  ('East', 'NNP'),
#  ('India', 'NNP'),
#  ('Company', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('cotton', 'NN'),
#  ('and', 'CC'),
#  ('silk', 'NN'),
#  ('traders', 'NNS'),
#  ('who', 'WP'),
#  ('sparked', 'VBD'),
#  ('the', 'DT'),
#  ('Opium', 'NNP'),
#  ('Wars', 'NNP'),
#  ('in', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('It', 'PRP'),
#  ('takes', 'VBZ'),
#  ('the', 'DT'),
#  ('risk', 'NN'),
#  ('and', 'CC'),
#  ('financial', 'JJ'),
#  ('burden', 'NN'),
#  ('off', 'IN'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('government', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('says', 'VBZ'),
#  ('.', '.'),
#  ('``', '``'),
#  ('If', 'IN'),
#  ('the', 'DT'),
#  ('companies', 'NNS'),
#  ('go', 'VBP'),
#  ('bankrupt', 'VBP'),
#  ('that', 'DT'),
#  ("'s", 'VBZ'),
#  ('their', 'PRP$'),
#  ('problem', 'NN'),
#  ('and', 'CC'),
#  ('(', '('),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('meantime', 'NN'),
#  (')', ')'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('can', 'MD'),
#  ('take', 'VB'),
#  ('advantage', 'NN'),
#  ('of', 'IN'),
#  ('(', '('),
#  ('them', 'PRP'),
#  (')', ')'),
#  ('spreading', 'VBG'),
#  ('a', 'DT'),
#  ('positive', 'JJ'),
#  ('view', 'NN'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('increasing', 'VBG'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('influence', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('When', 'WRB'),
#  ('Zeman', 'NNP'),
#  ('met', 'VBD'),
#  ('with', 'IN'),
#  ('Xi', 'NNP'),
#  ('Jinping', 'NNP'),
#  ('in', 'IN'),
#  ('Beijing', 'NNP'),
#  ('in', 'IN'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('Ye', 'NNP'),
#  ('was', 'VBD'),
#  ('photographed', 'VBN'),
#  ('with', 'IN'),
#  ('both', 'DT'),
#  ('presidents', 'NNS'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('proximity', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('center', 'NN'),
#  ('of', 'IN'),
#  ('Chinese', 'JJ'),
#  ('power', 'NN'),
#  ('had', 'VBD'),
#  ('never', 'RB'),
#  ('looked', 'VBN'),
#  ('stronger', 'JJR'),
#  ('.', '.'),
#  ('No', 'DT'),
#  ('prince', 'NN'),
#  ('The', 'DT'),
#  ('Czech', 'JJ'),
#  ('deals', 'NNS'),
#  ('caused', 'VBD'),
#  ('a', 'DT'),
#  ('buzz', 'NN'),
#  ('around', 'IN'),
#  ('Ye', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Journalists', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('calling', 'VBG'),
#  ('me', 'PRP'),
#  ('up', 'IN'),
#  ('asking', 'VBG'),
#  (':', ':'),
#  ("'What", 'WP'),
#  ('do', 'VBP'),
#  ('you', 'PRP'),
#  ('know', 'VB'),
#  ('about', 'IN'),
#  ('this', 'DT'),
#  ('?', '.'),
#  ("'", "''"),
#  ("''", "''"),
#  ('says', 'VBZ'),
#  ('Laban', 'NNP'),
#  ('Yu', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('head', 'NN'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('research', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Jefferies', 'NNP'),
#  ('Group', 'NNP'),
#  ('investment', 'NN'),
#  ('bank', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('would', 'MD'),
#  ('shrug', 'VB'),
#  ('.', '.'),
#  ('CEFC', 'NNP'),
#  ('China', 'NNP'),
#  ('Energy', 'NNP'),
#  ('“', 'NNP'),
#  ('came', 'VBD'),
#  ('out', 'RP'),
#  ('from', 'IN'),
#  ('nowhere', 'RB'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('says', 'VBZ'),
#  ('Yu', 'NNP'),
#  ('.', '.'),
#  ...]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (NP The/DT rise/NN)
#   and/CC
#   (NP fall/NN)
#   of/IN
#   a/DT
#   Belt/NNP
#   and/CC
#   Road/NNP
#   (NP billionaire/NN)
#   By/IN
#   Jenni/NNP
#   Marsh/NNP
#   ,/,
#   CNN/NNP
#   Photo/NNP
#   (NP illustration/AP/NN)
#   Images/NNP
#   In/IN
#   the/DT
#   mid-1990s/NNS
#   ,/,
#   Ye/NNP
#   Jianming/NNP
#   had/VBD
#   (NP a/DT simple/JJ job/NN)
#   in/IN
#   (NP a/DT forest/NN)
#   ,/,
#   or/CC
#   so/RB
#   his/PRP$
#   (NP story/NN)
#   goes/VBZ
#   ./.
#   Twenty/CD
#   years/NNS
#   later/RB
#   ,/,
#   he/PRP
#   sat/VBD
#   atop/VB
#   a/DT
#   $/$
#   44/CD
#   billion/CD
#   (NP business/NN)
#   (NP empire/NN)
#   ./.
#   (NP Today/NN)
#   ,/,
#   he/PRP
#   has/VBZ
#   vanished/VBN
#   and/CC
#   ,/,
#   as/IN
#   (NP that/DT empire/NN)
#   crumbles/NNS
#   ,/,
#   is/VBZ
#   reportedly/RB
#   under/IN
#   (NP investigation/NN)
#   by/IN
#   (NP the/DT Chinese/JJ government/NN)
#   ./.
#   How/WRB
#   all/DT
#   that/DT
#   happened/VBD
#   remains/VBZ
#   largely/RB
#   unknown/JJ
#   ./.
#   But/CC
#   one/CD
#   (NP thing/NN)
#   is/VBZ
#   clear/JJ
#   :/:
#   at/IN
#   its/PRP$
#   (NP height/NN)
#   ,/,
#   Ye/NNP
#   ’/NNP
#   s/VBD
#   (NP company/NN)
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ,/,
#   aligned/VBD
#   itself/PRP
#   so/RB
#   closely/RB
#   with/IN
#   (NP the/DT Chinese/JJ government/NN)
#   that/IN
#   it/PRP
#   was/VBD
#   often/RB
#   hard/JJ
#   to/TO
#   distinguish/VB
#   between/IN
#   the/DT
#   two/CD
#   ./.
#   (NP The/DT young/JJ tycoon/NN)
#   appeared/VBD
#   to/TO
#   be/VB
#   China/NNP
#   's/POS
#   (NP unofficial/JJ energy/NN)
#   (NP envoy/NN)
#   ,/,
#   (NP meeting/NN)
#   presidents/NNS
#   across/IN
#   (NP the/DT globe/NN)
#   and/CC
#   even/RB
#   becoming/VBG
#   (NP an/DT adviser/NN)
#   to/TO
#   (NP a/DT European/JJ government/NN)
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   he/PRP
#   ranked/VBD
#   No/NNP
#   ./.
#   2/CD
#   on/IN
#   the/DT
#   Fortune/NNP
#   (NP magazine/NN)
#   40/CD
#   Under/IN
#   40/CD
#   (NP list/NN)
#   ./.
#   But/CC
#   last/JJ
#   November/NNP
#   ,/,
#   Ye/NNP
#   ’/NNP
#   s/VBD
#   seemingly/RB
#   (NP unstoppable/JJ rise/NN)
#   came/VBD
#   to/TO
#   (NP a/DT screeching/JJ halt/NN)
#   ./.
#   His/PRP$
#   (NP undoing/NN)
#   came/VBD
#   after/IN
#   US/NNP
#   prosecutors/NNS
#   alleged/VBD
#   that/IN
#   an/DT
#   NGO/NNP
#   he/PRP
#   funded/VBD
#   had/VBD
#   used/VBN
#   its/PRP$
#   United/NNP
#   Nations/NNPS
#   (NP status/NN)
#   to/TO
#   offer/VB
#   millions/NNS
#   in/IN
#   (NP bribes/NN)
#   to/TO
#   African/JJ
#   leaders/NNS
#   ,/,
#   although/IN
#   he/PRP
#   is/VBZ
#   not/RB
#   charged/VBN
#   ./.
#   As/IN
#   (NP that/DT case/NN)
#   plays/VBZ
#   out/RP
#   in/IN
#   a/DT
#   Manhattan/NNP
#   (NP courthouse/NN)
#   ,/,
#   (NP the/DT world/NN)
#   is/VBZ
#   offered/VBN
#   (NP a/DT rare/JJ glimpse/NN)
#   into/IN
#   the/DT
#   complex/JJ
#   relations/NNS
#   between/IN
#   (NP private/JJ business/NN)
#   and/CC
#   (NP the/DT Chinese/JJ state/NN)
#   --/:
#   and/CC
#   with/IN
#   it/PRP
#   ,/,
#   (NP a/DT cautionary/JJ tale/NN)
#   of/IN
#   what/WP
#   happens/VBZ
#   when/WRB
#   (NP a/DT Chinese/JJ company/NN)
#   fails/VBZ
#   abroad/RB
#   ./.
#   (NP Czech/JJ invasion/NN)
#   Ye/NNP
#   came/VBD
#   to/TO
#   (NP international/JJ prominence/NN)
#   in/IN
#   (NP the/DT summer/NN)
#   of/IN
#   2015/CD
#   ,/,
#   following/VBG
#   (NP an/DT extraordinary/JJ buying/NN)
#   (NP spree/NN)
#   in/IN
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   ./.
#   As/IN
#   (NP the/DT chairman/NN)
#   of/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ,/,
#   Ye/NNP
#   snapped/VBD
#   up/RP
#   (NP the/DT country/NN)
#   's/POS
#   oldest/JJS
#   (NP football/NN)
#   (NP club/NN)
#   ,/,
#   Slavia/NNP
#   Praha/NNP
#   ;/:
#   (NP a/DT brewery/NN)
#   ;/:
#   (NP a/DT share/NN)
#   of/IN
#   the/DT
#   Travel/NNP
#   Service/NNP
#   (NP airline/NN)
#   (NP group/NN)
#   ;/:
#   (NP a/DT publishing/NN)
#   (NP house/NN)
#   ;/:
#   (NP a/DT neo-renaissance/JJ building/NN)
#   ;/:
#   (NP a/DT stake/NN)
#   in/IN
#   (NP the/DT investment/NN)
#   (NP bank/NN)
#   J/NNP
#   &/CC
#   T/NNP
#   Finance/NNP
#   Group/NNP
#   ;/:
#   and/CC
#   (NP a/DT building/NN)
#   in/IN
#   the/DT
#   Czech/NNP
#   (NP capital/NN)
#   Prague/NNP
#   ,/,
#   intended/VBD
#   for/IN
#   (NP use/NN)
#   as/IN
#   (NP the/DT company/NN)
#   's/POS
#   (NP European/JJ headquarters/NN)
#   ./.
#   A/DT
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   (NP sign/NN)
#   in/IN
#   Shanghai/NNP
#   ,/,
#   China/NNP
#   ./.
#   Newscom/NNP
#   Inside/IN
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   ,/,
#   the/DT
#   acquisitions/NNS
#   were/VBD
#   greeted/VBN
#   with/IN
#   (NP bemusement/NN)
#   :/:
#   Why/WRB
#   would/MD
#   (NP an/DT energy/NN)
#   (NP company/NN)
#   want/VBP
#   (NP a/DT brewery/NN)
#   ?/.
#   And/CC
#   why/WRB
#   was/VBD
#   (NP a/DT Chinese/JJ company/NN)
#   suddenly/RB
#   so/RB
#   welcome/JJ
#   in/IN
#   (NP a/DT country/NN)
#   that/WDT
#   had/VBD
#   ,/,
#   until/IN
#   recently/RB
#   ,/,
#   been/VBN
#   hostile/JJ
#   to/TO
#   China/NNP
#   ?/.
#   As/IN
#   with/IN
#   just/RB
#   about/IN
#   (NP everything/NN)
#   involving/VBG
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ,/,
#   the/DT
#   answers/NNS
#   would/MD
#   eventually/RB
#   point/VB
#   to/TO
#   (NP the/DT Chinese/JJ government/NN)
#   ./.
#   From/IN
#   its/PRP$
#   (NP founding/NN)
#   in/IN
#   1993/CD
#   until/IN
#   2003/CD
#   ,/,
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   was/VBD
#   led/VBN
#   by/IN
#   Vaclav/NNP
#   Havel/NNP
#   ,/,
#   (NP a/DT dissident/NN)
#   turned/VBD
#   (NP elected/JJ politician/NN)
#   ,/,
#   whose/WP$
#   (NP impassioned/JJ campaigning/NN)
#   had/VBD
#   helped/VBN
#   topple/VB
#   (NP the/DT country/NN)
#   's/POS
#   (NP former/JJ communist/JJ government/NN)
#   and/CC
#   (NP usher/NN)
#   in/IN
#   (NP a/DT new/JJ era/NN)
#   of/IN
#   (NP democracy/NN)
#   ./.
#   Throughout/IN
#   his/PRP$
#   (NP decade/NN)
#   in/IN
#   (NP office/NN)
#   ,/,
#   Havel/NNP
#   made/VBD
#   (NP no/DT attempt/NN)
#   to/TO
#   hide/VB
#   his/PRP$
#   (NP disdain/NN)
#   for/IN
#   China/NNP
#   's/POS
#   (NP own/JJ communist/NN)
#   rulers/NNS
#   ,/,
#   regularly/RB
#   meeting/VBG
#   with/IN
#   the/DT
#   Dalai/NNP
#   Lama/NNP
#   --/:
#   who/WP
#   is/VBZ
#   considered/VBN
#   by/IN
#   China/NNP
#   to/TO
#   be/VB
#   (NP a/DT dangerous/JJ separatist/NN)
#   ./.
#   Relations/NNS
#   changed/VBD
#   with/IN
#   (NP the/DT election/NN)
#   of/IN
#   Milos/NNP
#   Zeman/NNP
#   to/TO
#   (NP the/DT top/JJ office/NN)
#   in/IN
#   2013/CD
#   ./.
#   Touted/VBN
#   as/IN
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   's/POS
#   (NP first/JJ China-friendly/JJ president/NN)
#   ,/,
#   Zeman/NNP
#   was/VBD
#   keen/JJ
#   to/TO
#   facilitate/VB
#   increased/VBN
#   (NP trade/NN)
#   between/IN
#   Beijing/NNP
#   and/CC
#   Prague/NNP
#   ./.
#   (NP The/DT following/JJ year/NN)
#   ,/,
#   (NP a/DT Czech/JJ entity/NN)
#   would/MD
#   become/VB
#   the/DT
#   first/JJ
#   wholly/RB
#   (NP foreign-owned/JJ company/NN)
#   to/TO
#   provide/VB
#   loans/NNS
#   across/IN
#   China/NNP
#   ,/,
#   (NP a/DT huge/JJ coup/NN)
#   in/IN
#   (NP the/DT country/NN)
#   's/POS
#   relatively/RB
#   (NP untapped/JJ consumer/NN)
#   (NP credit/NN)
#   (NP market/NN)
#   ./.
#   Ye/NNP
#   sensed/VBD
#   (NP an/DT opportunity/NN)
#   ./.
#   He/PRP
#   was/VBD
#   quietly/RB
#   made/VBN
#   (NP a/DT special/JJ economic/JJ adviser/NN)
#   to/TO
#   Zeman/NNP
#   ,/,
#   (NP something/NN)
#   that/WDT
#   would/MD
#   only/RB
#   be/VB
#   announced/VBN
#   six/CD
#   months/NNS
#   after/IN
#   (NP the/DT fact/NN)
#   ./.
#   Miroslav/NNP
#   Kalousek/NNP
#   ,/,
#   (NP a/DT Czech/JJ opposition/NN)
#   MP/NNP
#   ,/,
#   says/VBZ
#   he/PRP
#   considers/VBZ
#   Ye/NNP
#   ’/NNP
#   (NP s/JJ role/NN)
#   in/IN
#   his/PRP$
#   (NP country/NN)
#   ’/NNP
#   (NP s/JJ government/NN)
#   as/IN
#   ``/``
#   scandalous/JJ
#   and/CC
#   (NP a/DT security/NN)
#   (NP risk/NN)
#   ./.
#   ''/''
#   Shortly/RB
#   after/IN
#   Ye/NNP
#   's/POS
#   (NP appointment/NN)
#   came/VBD
#   his/PRP$
#   (NP high-profile/JJ splurge/NN)
#   ./.
#   The/DT
#   deals/NNS
#   made/VBD
#   (NP no/DT commercial/JJ sense/NN)
#   ,/,
#   says/VBZ
#   Martin/NNP
#   Hala/NNP
#   ,/,
#   a/DT
#   leading/VBG
#   Czech/JJ
#   academic/JJ
#   in/IN
#   Chinese/JJ
#   studies/NNS
#   ./.
#   But/CC
#   they/PRP
#   sent/VBD
#   (NP a/DT clear/JJ message/NN)
#   from/IN
#   Beijing/NNP
#   to/TO
#   (NP the/DT international/JJ community/NN)
#   that/IN
#   China/NNP
#   now/RB
#   had/VBD
#   (NP a/DT firm/JJ friend/NN)
#   in/IN
#   Europe/NNP
#   ./.
#   That/DT
#   was/VBD
#   important/JJ
#   ./.
#   Chinese/JJ
#   President/NNP
#   Xi/NNP
#   Jinping/NNP
#   's/POS
#   (NP flagship/NN)
#   Belt/NNP
#   and/CC
#   Road/NNP
#   (NP initiative/NN)
#   aims/NNS
#   to/TO
#   export/VB
#   Chinese/NNP
#   (NP commerce/NN)
#   ,/,
#   goods/NNS
#   and/CC
#   (NP influence/NN)
#   across/IN
#   (NP the/DT globe/NN)
#   ./.
#   (NP A/DT foothold/NN)
#   in/IN
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   gave/VBD
#   China/NNP
#   (NP a/DT gateway/NN)
#   to/TO
#   Europe/NNP
#   ,/,
#   and/CC
#   (NP a/DT valuable/JJ political/JJ ally/NN)
#   within/IN
#   the/DT
#   European/NNP
#   Union/NNP
#   ,/,
#   Beijing/NNP
#   's/POS
#   largest/JJS
#   (NP trading/NN)
#   (NP partner/NN)
#   ./.
#   Chinese/JJ
#   President/NNP
#   Xi/NNP
#   Jinping/NNP
#   ,/,
#   (NP second/NN)
#   from/IN
#   (NP right/NN)
#   ,/,
#   with/IN
#   Czech/NNP
#   President/NNP
#   Milos/NNP
#   Zeman/NNP
#   ,/,
#   third/JJ
#   from/IN
#   (NP left/NN)
#   ,/,
#   at/IN
#   the/DT
#   Great/NNP
#   Hall/NNP
#   of/IN
#   the/DT
#   People/NNP
#   in/IN
#   Beijing/NNP
#   in/IN
#   September/NNP
#   ,/,
#   2015/CD
#   ./.
#   Ye/VB
#   Jianming/NNP
#   is/VBZ
#   on/IN
#   the/DT
#   far/RB
#   (NP left/NN)
#   ./.
#   Lucie/NNP
#   Mikolaskova/NNP
#   (/(
#   CTK/NNP
#   via/IN
#   AP/NNP
#   Images/NNP
#   )/)
#   Stephen/NNP
#   Platt/NNP
#   ,/,
#   (NP an/DT American/JJ historian/NN)
#   and/CC
#   (NP professor/NN)
#   of/IN
#   (NP Chinese/JJ history/NN)
#   at/IN
#   the/DT
#   University/NNP
#   of/IN
#   Massachusetts/NNP
#   Amherst/NNP
#   ,/,
#   says/VBZ
#   there/EX
#   is/VBZ
#   (NP a/DT long/JJ history/NN)
#   of/IN
#   private/JJ
#   businessmen/NNS
#   advancing/VBG
#   (NP the/DT influence/NN)
#   of/IN
#   their/PRP$
#   (NP country/NN)
#   abroad/RB
#   ,/,
#   dating/VBG
#   back/RB
#   to/TO
#   the/DT
#   British/JJ
#   East/NNP
#   India/NNP
#   Company/NNP
#   and/CC
#   (NP the/DT cotton/NN)
#   and/CC
#   (NP silk/NN)
#   traders/NNS
#   who/WP
#   sparked/VBD
#   the/DT
#   Opium/NNP
#   Wars/NNP
#   in/IN
#   China/NNP
#   ./.
#   ``/``
#   It/PRP
#   takes/VBZ
#   (NP the/DT risk/NN)
#   and/CC
#   (NP financial/JJ burden/NN)
#   off/IN
#   (NP the/DT Chinese/JJ government/NN)
#   ,/,
#   ''/''
#   he/PRP
#   says/VBZ
#   ./.
#   ``/``
#   If/IN
#   the/DT
#   companies/NNS
#   go/VBP
#   bankrupt/VBP
#   that/DT
#   's/VBZ
#   their/PRP$
#   (NP problem/NN)
#   and/CC
#   (/(
#   in/IN
#   (NP the/DT meantime/NN)
#   )/)
#   (NP the/DT government/NN)
#   can/MD
#   take/VB
#   (NP advantage/NN)
#   of/IN
#   (/(
#   them/PRP
#   )/)
#   spreading/VBG
#   (NP a/DT positive/JJ view/NN)
#   of/IN
#   China/NNP
#   and/CC
#   increasing/VBG
#   China/NNP
#   's/POS
#   (NP influence/NN)
#   ./.
#   ''/''
#   When/WRB
#   Zeman/NNP
#   met/VBD
#   with/IN
#   Xi/NNP
#   Jinping/NNP
#   in/IN
#   Beijing/NNP
#   in/IN
#   2015/CD
#   ,/,
#   Ye/NNP
#   was/VBD
#   photographed/VBN
#   with/IN
#   both/DT
#   presidents/NNS
#   ./.
#   His/PRP$
#   (NP proximity/NN)
#   to/TO
#   (NP the/DT center/NN)
#   of/IN
#   (NP Chinese/JJ power/NN)
#   had/VBD
#   never/RB
#   looked/VBN
#   stronger/JJR
#   ./.
#   (NP No/DT prince/NN)
#   The/DT
#   Czech/JJ
#   deals/NNS
#   caused/VBD
#   (NP a/DT buzz/NN)
#   around/IN
#   Ye/NNP
#   ./.
#   ``/``
#   Journalists/NNS
#   would/MD
#   be/VB
#   calling/VBG
#   me/PRP
#   up/IN
#   asking/VBG
#   :/:
#   'What/WP
#   do/VBP
#   you/PRP
#   know/VB
#   about/IN
#   this/DT
#   ?/.
#   '/''
#   ''/''
#   says/VBZ
#   Laban/NNP
#   Yu/NNP
#   ,/,
#   (NP the/DT head/NN)
#   of/IN
#   China/NNP
#   (NP research/NN)
#   at/IN
#   the/DT
#   Jefferies/NNP
#   Group/NNP
#   (NP investment/NN)
#   (NP bank/NN)
#   ./.
#   He/PRP
#   would/MD
#   shrug/VB
#   ./.
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   “/NNP
#   came/VBD
#   out/RP
#   from/IN
#   nowhere/RB
#   ,/,
#   ”/NNP
#   says/VBZ
#   Yu/NNP
#   ./.
#   By/IN
#   2018/CD
#   ,/,
#   it/PRP
#   was/VBD
#   widely/RB
#   reported/VBN
#   that/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   had/VBD
#   (NP a/DT global/JJ property/NN)
#   (NP portfolio/NN)
#   worth/JJ
#   $/$
#   3.2/CD
#   billion/CD
#   ,/,
#   including/VBG
#   (NP office/NN)
#   (NP space/NN)
#   in/IN
#   central/JJ
#   Hong/NNP
#   Kong/NNP
#   and/CC
#   a/DT
#   Trump/NNP
#   World/NNP
#   Tower/NNP
#   (NP apartment/NN)
#   in/IN
#   Manhattan/NNP
#   ./.
#   (NP The/DT company/NN)
#   employed/VBD
#   nearly/RB
#   50,000/CD
#   people/NNS
#   ,/,
#   was/VBD
#   ranked/VBN
#   No/NNP
#   ./.
#   222/CD
#   on/IN
#   the/DT
#   2017/CD
#   Fortune/NNP
#   500/CD
#   (NP list/NN)
#   and/CC
#   in/IN
#   2015/CD
#   made/VBD
#   about/IN
#   $/$
#   40/CD
#   billion/CD
#   in/IN
#   (NP revenue/NN)
#   ./.
#   (NP “/NN)
#   (/(
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   )/)
#   came/VBD
#   out/RP
#   from/IN
#   nowhere/RB
#   ”/JJ
#   Laban/NNP
#   Yu/NNP
#   ,/,
#   (NP head/NN)
#   of/IN
#   China/NNP
#   (NP research/NN)
#   at/IN
#   the/DT
#   Jefferies/NNP
#   Group/NNP
#   In/IN
#   2016/CD
#   ,/,
#   Ye/NNP
#   granted/VBD
#   Fortune/NNP
#   (NP magazine/NN)
#   what/WP
#   remains/VBZ
#   his/PRP$
#   (NP only/JJ interview/NN)
#   with/IN
#   Western/JJ
#   media/NNS
#   ./.
#   It/PRP
#   was/VBD
#   (NP an/DT opportunity/NN)
#   to/TO
#   address/VB
#   questions/NNS
#   of/IN
#   his/PRP$
#   (NP alleged/JJ government/NN)
#   ties/NNS
#   ./.
#   For/IN
#   years/NNS
#   ,/,
#   rumors/NNS
#   had/VBD
#   circulated/VBN
#   in/IN
#   China/NNP
#   that/IN
#   Ye/NNP
#   was/VBD
#   a/DT
#   People/NNP
#   ’/NNP
#   s/JJ
#   Liberation/NNP
#   Army/NNP
#   (/(
#   PLA/NNP
#   )/)
#   (NP princeling/NN)
#   --/:
#   (NP the/DT name/NN)
#   given/VBN
#   to/TO
#   offspring/VBG
#   of/IN
#   the/DT
#   founding/VBG
#   fathers/NNS
#   of/IN
#   the/DT
#   People/NNP
#   's/POS
#   Republic/NNP
#   of/IN
#   China/NNP
#   ,/,
#   who/WP
#   used/VBD
#   their/PRP$
#   (NP power/NN)
#   to/TO
#   amass/VB
#   (NP vast/JJ wealth/NN)
#   ./.
#   Many/JJ
#   princelings/NNS
#   hold/VBP
#   top/JJ
#   positions/NNS
#   in/IN
#   state-owned/JJ
#   enterprises/NNS
#   (/(
#   SOEs/NNP
#   )/)
#   or/CC
#   are/VBP
#   high-ranking/JJ
#   politicians/NNS
#   ./.
#   President/NNP
#   Xi/NNP
#   ,/,
#   for/IN
#   (NP instance/NN)
#   ,/,
#   is/VBZ
#   (NP the/DT son/NN)
#   (NP a/DT former/JJ vice/NN)
#   (NP premier/NN)
#   of/IN
#   the/DT
#   State/NNP
#   Council/NNP
#   ./.
#   In/IN
#   China/NNP
#   ,/,
#   princeling/VBG
#   (NP status/NN)
#   is/VBZ
#   often/RB
#   considered/VBN
#   the/DT
#   fastest/JJS
#   (NP way/NN)
#   to/TO
#   get/VB
#   rich/JJ
#   ./.
#   Onlookers/NNS
#   theorized/VBD
#   that/IN
#   Ye/NNP
#   Jianming/NNP
#   's/POS
#   (NP grandfather/NN)
#   was/VBD
#   a/DT
#   high-ranking/JJ
#   Communist/NNP
#   Party/NNP
#   (NP official/NN)
#   called/VBD
#   Ye/NNP
#   Jianying/NNP
#   ./.
#   (NP A/DT biography/NN)
#   of/IN
#   the/DT
#   younger/JJR
#   Ye/NNP
#   in/IN
#   a/DT
#   2012/CD
#   (NP financial/JJ report/NN)
#   seemed/VBD
#   to/TO
#   support/VB
#   claims/NNS
#   of/IN
#   high-level/JJ
#   PLA/NNP
#   ties/NNS
#   ./.
#   It/PRP
#   states/VBZ
#   that/IN
#   from/IN
#   2003/CD
#   until/IN
#   2005/CD
#   he/PRP
#   was/VBD
#   (NP the/DT deputy/NN)
#   (NP secretary/NN)
#   (NP general/NN)
#   of/IN
#   the/DT
#   China/NNP
#   Association/NNP
#   for/IN
#   International/NNP
#   Friendly/NNP
#   Contact/NNP
#   (/(
#   CAIFC/NNP
#   )/)
#   ./.
#   (NP That/DT group/NN)
#   is/VBZ
#   (NP a/DT purported/JJ political/JJ arm/NN)
#   of/IN
#   the/DT
#   Chinese/JJ
#   military/JJ
#   ,/,
#   according/VBG
#   to/TO
#   (NP a/DT report/NN)
#   by/IN
#   (NP the/DT Project/NN)
#   2049/CD
#   Institute/NNP
#   ,/,
#   (NP a/DT US-based/JJ organization/NN)
#   that/WDT
#   researches/VBZ
#   Asia/NNP
#   (NP security/NN)
#   issues/NNS
#   ./.
#   Stylistic/JJ
#   similarities/NNS
#   between/IN
#   the/DT
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   and/CC
#   CAIFC/NNP
#   logos/VBP
#   did/VBD
#   (NP nothing/NN)
#   to/TO
#   dispel/VB
#   (NP the/DT idea/NN)
#   that/IN
#   Ye/NNP
#   was/VBD
#   linked/VBN
#   to/TO
#   the/DT
#   military/JJ
#   ./.
#   In/IN
#   (NP an/DT email/NN)
#   ,/,
#   CAIFC/NNP
#   denied/VBD
#   that/IN
#   Ye/NNP
#   Jianming/NNP
#   had/VBD
#   been/VBN
#   (NP deputy/JJ chair/NN)
#   of/IN
#   (NP the/DT organization/NN)
#   and/CC
#   that/IN
#   it/PRP
#   had/VBD
#   military/JJ
#   ties/NNS
#   ./.
#   CEFC/NNP
#   ,/,
#   CAIFC/NNP
#   Ye/NNP
#   wanted/VBD
#   people/NNS
#   to/TO
#   believe/VB
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   was/VBD
#   intimately/RB
#   related/VBN
#   to/TO
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   (NP the/DT Chinese/JJ state/NN)
#   ,/,
#   says/VBZ
#   Andrew/NNP
#   Chubb/NNP
#   ,/,
#   (NP a/DT postdoctoral/JJ fellow/NN)
#   in/IN
#   the/DT
#   Columbia-Harvard/NNP
#   China/NNP
#   and/CC
#   the/DT
#   World/NNP
#   Program/NNP
#   ./.
#   But/CC
#   when/WRB
#   asked/VBD
#   about/IN
#   (NP the/DT issue/NN)
#   ,/,
#   Ye/NNP
#   told/VBD
#   Fortune/NNP
#   he/PRP
#   didn/VBZ
#   ’/JJ
#   t/NNS
#   have/VBP
#   military/JJ
#   ties/NNS
#   ./.
#   From/IN
#   the/DT
#   yellow/JJ
#   stars/NNS
#   in/IN
#   its/PRP$
#   (NP logo/NN)
#   to/TO
#   (NP the/DT fact/NN)
#   it/PRP
#   had/VBD
#   China/NNP
#   in/IN
#   its/PRP$
#   (NP name/NN)
#   --/:
#   (NP a/DT privilege/NN)
#   normally/RB
#   reserved/VBN
#   for/IN
#   state-owned/JJ
#   companies/NNS
#   --/:
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ’/NNP
#   s/VBD
#   messaging/VBG
#   strongly/RB
#   suggested/VBN
#   (NP state/NN)
#   ties/NNS
#   ./.
#   So/RB
#   why/WRB
#   was/VBD
#   Ye/NNP
#   denying/VBG
#   links/NNS
#   ?/.
#   (NP “/NN)
#   To/TO
#   me/PRP
#   ,/,
#   it/PRP
#   's/VBZ
#   (NP a/DT story/NN)
#   of/IN
#   how/WRB
#   people/NNS
#   who/WP
#   are/VBP
#   really/RB
#   unimportant/JJ
#   can/MD
#   make/VB
#   things/NNS
#   happen/VB
#   ”/RB
#   Bonnie/NNP
#   Glaser/NNP
#   ,/,
#   (NP senior/JJ adviser/NN)
#   for/IN
#   the/DT
#   Center/NNP
#   for/IN
#   Strategic/NNP
#   and/CC
#   International/NNP
#   Studies/NNP
#   Perhaps/RB
#   some/DT
#   of/IN
#   his/PRP$
#   ties/NNS
#   were/VBD
#   not/RB
#   that/IN
#   strong/JJ
#   ./.
#   Bonnie/NNP
#   Glaser/NNP
#   ,/,
#   (NP director/NN)
#   of/IN
#   the/DT
#   China/NNP
#   Power/NNP
#   Project/NNP
#   in/IN
#   Washington/NNP
#   ,/,
#   says/VBZ
#   she/PRP
#   was/VBD
#   introduced/VBN
#   to/TO
#   Ye/VB
#   in/IN
#   2010/CD
#   ,/,
#   in/IN
#   Shanghai/NNP
#   ,/,
#   through/IN
#   a/DT
#   PLA/NNP
#   (NP admiral/NN)
#   who/WP
#   was/VBD
#   writing/VBG
#   (NP the/DT proposal/NN)
#   for/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   to/TO
#   set/VB
#   up/RP
#   (NP an/DT NGO/NN)
#   at/IN
#   the/DT
#   United/NNP
#   Nations/NNPS
#   ./.
#   (NP The/DT admiral/NN)
#   was/VBD
#   n't/RB
#   overly/RB
#   influential/JJ
#   or/CC
#   wealthy/JJ
#   ,/,
#   she/PRP
#   says/VBZ
#   ,/,
#   but/CC
#   spoke/VBD
#   good/JJ
#   English/NNP
#   and/CC
#   knew/VBD
#   Western/JJ
#   procedures/NNS
#   ./.
#   (NP The/DT following/JJ year/NN)
#   ,/,
#   Ye/NNP
#   's/POS
#   NGO/NNP
#   was/VBD
#   officially/RB
#   recognized/VBN
#   by/IN
#   the/DT
#   UN/NNP
#   ./.
#   ``/``
#   To/TO
#   me/PRP
#   ,/,
#   it/PRP
#   's/VBZ
#   (NP a/DT story/NN)
#   of/IN
#   how/WRB
#   people/NNS
#   who/WP
#   are/VBP
#   really/RB
#   unimportant/JJ
#   can/MD
#   make/VB
#   things/NNS
#   happen/VB
#   ,/,
#   ''/''
#   says/VBZ
#   Glaser/NNP
#   ,/,
#   who/WP
#   has/VBZ
#   advised/VBN
#   the/DT
#   US/NNP
#   (NP government/NN)
#   on/IN
#   Chinese/JJ
#   affairs/NNS
#   ./.
#   In/IN
#   his/PRP$
#   Fortune/NNP
#   (NP interview/NN)
#   ,/,
#   Ye/NNP
#   provided/VBD
#   (NP an/DT alternative/JJ story/NN)
#   to/TO
#   the/DT
#   PLA/NNP
#   (NP princeling/NN)
#   rumors/NNS
#   :/:
#   After/IN
#   (NP a/DT stint/NN)
#   in/IN
#   the/DT
#   forest/JJS
#   (NP police/NN)
#   ,/,
#   while/IN
#   still/RB
#   in/IN
#   his/PRP$
#   early/JJ
#   20s/CD
#   ,/,
#   he/PRP
#   somehow/RB
#   managed/VBD
#   to/TO
#   buy/VB
#   (NP oil/NN)
#   assets/NNS
#   at/IN
#   (NP auction/NN)
#   from/IN
#   (NP a/DT businessman/NN)
#   who/WP
#   had/VBD
#   fled/VBN
#   Ye/NNP
#   ’/NNP
#   s/VBD
#   (NP home/NN)
#   (NP province/NN)
#   of/IN
#   Fujian/NNP
#   in/IN
#   southern/JJ
#   China/NNP
#   ./.
#   Ye/NNP
#   insisted/VBD
#   it/PRP
#   was/VBD
#   Hong/NNP
#   Kong/NNP
#   and/CC
#   Fujian/JJ
#   businessmen/NNS
#   who/WP
#   gave/VBD
#   him/PRP
#   (NP the/DT cash/NN)
#   ./.
#   “/NNS
#   But/CC
#   why/WRB
#   they/PRP
#   would/MD
#   put/VB
#   a/DT
#   20-something/JJ
#   in/IN
#   (NP charge/NN)
#   of/IN
#   that/DT
#   is/VBZ
#   totally/RB
#   mysterious/JJ
#   ,/,
#   ”/NNP
#   says/VBZ
#   Chubb/NNP
#   ./.
#   Chinese/JJ
#   journalists/NNS
#   who/WP
#   subsequently/RB
#   traveled/VBD
#   to/TO
#   Ye/NNP
#   's/POS
#   parents/NNS
#   ’/VBP
#   (NP home/NN)
#   claimed/VBD
#   his/PRP$
#   (NP family/NN)
#   were/VBD
#   modest/JJ
#   fishermen/NNS
#   ./.
#   The/DT
#   Belt/NNP
#   and/CC
#   Road/NNP
#   On/IN
#   a/DT
#   quiet/JJ
#   ,/,
#   (NP tree-lined/JJ street/NN)
#   in/IN
#   Shanghai/NNP
#   's/POS
#   former/JJ
#   French/JJ
#   Concession/NNP
#   (NP district/NN)
#   ,/,
#   amid/IN
#   (NP the/DT city/NN)
#   's/POS
#   most/RBS
#   historic/JJ
#   and/CC
#   (NP expensive/JJ real/JJ estate/NN)
#   ,/,
#   lies/VBZ
#   the/DT
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   (NP compound/NN)
#   ./.
#   Designed/VBN
#   as/IN
#   (NP a/DT Western-style/JJ palace/NN)
#   ,/,
#   (NP the/DT compound/NN)
#   features/VBZ
#   20/CD
#   villas/NNS
#   replete/JJ
#   with/IN
#   white/JJ
#   marble/JJ
#   pillars/NNS
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (NP a/DT Chinese/JJ pavilion/NN)
#   ./.
#   Once/IN
#   (NP the/DT headquarters/NN)
#   of/IN
#   (NP the/DT firm/NN)
#   ,/,
#   (NP today/NN)
#   all/DT
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   signs/NNS
#   have/VBP
#   been/VBN
#   stripped/VBN
#   from/IN
#   (NP the/DT gate/NN)
#   ./.
#   A/DT
#   CEFC/NNP
#   (NP charity/NN)
#   is/VBZ
#   located/VBN
#   100/CD
#   meters/NNS
#   away/RB
#   from/IN
#   the/DT
#   CEFC/NNP
#   HQ/NNP
#   (NP compound/NN)
#   ./.
#   (NP This/DT notice/NN)
#   says/VBZ
#   (NP the/DT power/NN)
#   (NP supply/NN)
#   is/VBZ
#   to/TO
#   be/VB
#   cut/VBN
#   owing/VBG
#   from/IN
#   November/NNP
#   28/CD
#   due/JJ
#   to/TO
#   overdue/JJ
#   bills/NNS
#   ./.
#   CNN/VB
#   (NP A/DT sketch/NN)
#   of/IN
#   (NP the/DT building/NN)
#   from/IN
#   CEFC/NNP
#   ’/NNP
#   s/VBD
#   website/RB
#   ./.
#   CEFC/VB
#   (NP The/DT side/NN)
#   (NP gate/NN)
#   of/IN
#   the/DT
#   CEFC/NNP
#   (NP compound/NN)
#   in/IN
#   November/NNP
#   2018/CD
#   ./.
#   CNN/NNP
#   Ye/NNP
#   relocated/VBD
#   to/TO
#   Shanghai/NNP
#   from/IN
#   Fujian/NNP
#   around/IN
#   2009/CD
#   ,/,
#   according/VBG
#   to/TO
#   records/NNS
#   seen/VBN
#   by/IN
#   (NP Chinese/JJ financial/JJ news/NN)
#   (NP outlet/NN)
#   Caixin/NNP
#   ./.
#   ``/``
#   He/PRP
#   was/VBD
#   (NP part/NN)
#   of/IN
#   (NP a/DT Fujian/JJ clique/NN)
#   that/IN
#   all/DT
#   rose/VBD
#   together/RB
#   ,/,
#   ''/''
#   says/VBZ
#   Chubb/NNP
#   ,/,
#   whose/WP$
#   (NP blog/NN)
#   ,/,
#   South/NNP
#   Sea/NNP
#   Conversations/NNP
#   ,/,
#   has/VBZ
#   closely/RB
#   tracked/VBN
#   the/DT
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   (NP story/NN)
#   ./.
#   (NP The/DT group/NN)
#   emerged/VBD
#   while/IN
#   Xi/NNP
#   Jinping/NNP
#   was/VBD
#   still/RB
#   in/IN
#   (NP the/DT Fujian/JJ government/NN)
#   ./.
#   It/PRP
#   moved/VBD
#   to/TO
#   Shanghai/NNP
#   around/IN
#   (NP the/DT same/JJ time/NN)
#   as/IN
#   (NP Xi/NN)
#   did/VBD
#   --/:
#   although/IN
#   it/PRP
#   is/VBZ
#   unclear/JJ
#   whether/IN
#   or/CC
#   not/RB
#   their/PRP$
#   lives/NNS
#   intersected/VBN
#   ./.
#   It/PRP
#   was/VBD
#   in/IN
#   Shanghai/NNP
#   that/IN
#   Ye/NNP
#   's/POS
#   (NP business/NN)
#   (NP empire/NN)
#   mushroomed/VBD
#   ./.
#   He/PRP
#   became/VBD
#   (NP the/DT epicenter/NN)
#   of/IN
#   (NP a/DT multi-billion-dollar/JJ constellation/NN)
#   of/IN
#   companies/NNS
#   based/VBN
#   in/IN
#   the/DT
#   Czech/NNP
#   Republic/NNP
#   ,/,
#   Singapore/NNP
#   ,/,
#   Hong/NNP
#   Kong/NNP
#   ,/,
#   Bermuda/NNP
#   and/CC
#   mainland/VB
#   China/NNP
#   ./.
#   In/IN
#   2011/CD
#   ,/,
#   his/PRP$
#   (NP company/NN)
#   's/POS
#   NGO/NNP
#   ,/,
#   the/DT
#   China/NNP
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   ,/,
#   was/VBD
#   awarded/VBN
#   (NP consultative/JJ status/NN)
#   at/IN
#   the/DT
#   UN/NNP
#   ./.
#   It/PRP
#   was/VBD
#   a/DT
#   highly/RB
#   unusual/JJ
#   ,/,
#   if/IN
#   not/RB
#   unprecedented/VBN
#   ,/,
#   move/VB
#   for/IN
#   (NP a/DT private/JJ energy/NN)
#   (NP company/NN)
#   ./.
#   Why/WRB
#   (NP a/DT Chinese/JJ energy/NN)
#   (NP company/NN)
#   would/MD
#   fund/VB
#   an/DT
#   NGO/NNP
#   at/IN
#   the/DT
#   UN/NNP
#   puzzled/VBD
#   Glaser/NNP
#   ,/,
#   the/DT
#   US/NNP
#   academic/VB
#   who/WP
#   had/VBD
#   met/VBN
#   Ye/NNP
#   ./.
#   Officially/RB
#   ,/,
#   its/PRP$
#   (NP mission/NN)
#   was/VBD
#   to/TO
#   serve/VB
#   as/IN
#   ``/``
#   (NP a/DT high-end/JJ strategic/JJ think/NN)
#   (NP tank/NN)
#   ''/''
#   on/IN
#   (NP energy/NN)
#   ./.
#   Much/JJ
#   of/IN
#   the/DT
#   NGO/NNP
#   ’/NNP
#   s/VBD
#   (NP time/NN)
#   was/VBD
#   spent/VBN
#   holding/VBG
#   conferences/NNS
#   on/IN
#   the/DT
#   Belt/NNP
#   and/CC
#   Road/NNP
#   (NP initiative/NN)
#   ./.
#   The/DT
#   events/NNS
#   were/VBD
#   surreal/JJ
#   for/IN
#   being/VBG
#   so/RB
#   ``/``
#   pro-China/JJ
#   ,/,
#   ''/''
#   says/VBZ
#   Glaser/NNP
#   ./.
#   Still/RB
#   ,/,
#   they/PRP
#   attracted/VBD
#   (NP an/DT impressive/JJ crowd/NN)
#   ./.
#   (NP A/DT former/JJ head/NN)
#   of/IN
#   (NP an/DT oil/NN)
#   (NP conglomerate/NN)
#   ,/,
#   US/NNP
#   and/CC
#   Russian/JJ
#   ex-diplomats/NNS
#   ,/,
#   and/CC
#   retirees/NNS
#   of/IN
#   America/NNP
#   's/POS
#   National/NNP
#   Security/NNP
#   Agency/NNP
#   and/CC
#   the/DT
#   CIA/NNP
#   all/DT
#   appeared/VBD
#   at/IN
#   the/DT
#   NGO/NNP
#   ’/NNP
#   s/JJ
#   events/NNS
#   ./.
#   (NP “/NN)
#   I/PRP
#   did/VBD
#   n't/RB
#   have/VB
#   (NP a/DT clear/JJ idea/NN)
#   ,/,
#   and/CC
#   for/IN
#   (NP that/DT matter/NN)
#   still/RB
#   do/VBP
#   n't/RB
#   ,/,
#   what/WP
#   the/DT
#   China/NNP
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   ”/NNP
#   Hugh/NNP
#   White/NNP
#   ,/,
#   (NP professor/NN)
#   of/IN
#   strategic/JJ
#   studies/NNS
#   at/IN
#   the/DT
#   Australian/JJ
#   National/NNP
#   University/NNP
#   ,/,
#   in/IN
#   Canberra/NNP
#   ``/``
#   I/PRP
#   remember/VBP
#   .../:
#   (NP thinking/NN)
#   ,/,
#   (NP wow/NN)
#   ,/,
#   they/PRP
#   're/VBP
#   bringing/VBG
#   in/IN
#   really/RB
#   senior/JJ
#   people/NNS
#   now/RB
#   ,/,
#   ''/''
#   says/VBZ
#   Glaser/NNP
#   ./.
#   But/CC
#   many/JJ
#   scholars/NNS
#   who/WP
#   attended/VBD
#   the/DT
#   NGO/NNP
#   ’/NNP
#   (NP s/NN)
#   forums/NNS
#   had/VBD
#   never/RB
#   heard/VBN
#   of/IN
#   Ye/NNP
#   ./.
#   They/PRP
#   assumed/VBD
#   the/DT
#   China/NNP
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   (NP a/DT vessel/NN)
#   of/IN
#   (NP the/DT Chinese/JJ government/NN)
#   ,/,
#   says/VBZ
#   Hugh/NNP
#   White/NNP
#   ,/,
#   of/IN
#   the/DT
#   Australian/NNP
#   National/NNP
#   University/NNP
#   ,/,
#   who/WP
#   took/VBD
#   (NP part/NN)
#   in/IN
#   one/CD
#   (NP such/JJ event/NN)
#   in/IN
#   2015/CD
#   ./.
#   He/PRP
#   pauses/VBZ
#   before/IN
#   adding/VBG
#   :/:
#   ``/``
#   But/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   have/VB
#   (NP a/DT clear/JJ idea/NN)
#   ,/,
#   and/CC
#   for/IN
#   (NP that/DT matter/NN)
#   still/RB
#   do/VBP
#   n't/RB
#   ,/,
#   what/WP
#   the/DT
#   China/NNP
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   ''/''
#   At/IN
#   the/DT
#   UN/NNP
#   ,/,
#   employees/NNS
#   of/IN
#   Ye/NNP
#   ’/NNP
#   (NP s/NN)
#   NGO/NNP
#   were/VBD
#   rubbing/VBG
#   shoulders/NNS
#   with/IN
#   some/DT
#   of/IN
#   the/DT
#   most/RBS
#   important/JJ
#   men/NNS
#   in/IN
#   (NP the/DT world/NN)
#   ./.
#   In/IN
#   the/DT
#   four/CD
#   years/NNS
#   after/IN
#   the/DT
#   NGO/NNP
#   arrived/VBD
#   in/IN
#   New/NNP
#   York/NNP
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   's/POS
#   (NP revenue/NN)
#   grew/VBD
#   by/IN
#   25/CD
#   (NP %/NN)
#   annually/RB
#   ,/,
#   according/VBG
#   to/TO
#   (NP the/DT company/NN)
#   's/POS
#   (NP website/NN)
#   ./.
#   As/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   thrived/VBD
#   ,/,
#   Ye/NNP
#   traveled/VBD
#   (NP the/DT world/NN)
#   on/IN
#   his/PRP$
#   private/JJ
#   Airbus/NNP
#   (NP glad-handing/NN)
#   leaders/NNS
#   ,/,
#   including/VBG
#   President/NNP
#   Erdogan/NNP
#   of/IN
#   Turkey/NNP
#   ,/,
#   the/DT
#   former/JJ
#   US/NNP
#   (NP secretary/NN)
#   of/IN
#   (NP state/NN)
#   Henry/NNP
#   Kissinger/NNP
#   ,/,
#   (NP the/DT prime/JJ minister/NN)
#   of/IN
#   Kazakhstan/NNP
#   ,/,
#   and/CC
#   Alan/NNP
#   Greenspan/NNP
#   ,/,
#   the/DT
#   former/JJ
#   US/NNP
#   Federal/NNP
#   Reserve/NNP
#   (NP chairman/NN)
#   ./.
#   With/IN
#   better/JJR
#   political/JJ
#   connections/NNS
#   came/VBD
#   bigger/JJR
#   international/JJ
#   deals/NNS
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   for/IN
#   (NP example/NN)
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   established/VBD
#   (NP trade/NN)
#   deals/NNS
#   in/IN
#   Georgia/NNP
#   and/CC
#   reached/VBD
#   a/DT
#   $/$
#   680/CD
#   million/CD
#   (NP agreement/NN)
#   --/:
#   which/WDT
#   has/VBZ
#   since/IN
#   fallen/VBN
#   through/IN
#   --/:
#   with/IN
#   a/DT
#   Kazakh/NNP
#   (NP state/NN)
#   (NP oil/NN)
#   and/CC
#   (NP gas/NN)
#   (NP firm/NN)
#   ./.
#   (NP The/DT next/JJ year/NN)
#   ,/,
#   it/PRP
#   spent/VBD
#   $/$
#   900/CD
#   million/CD
#   on/IN
#   (NP a/DT stake/NN)
#   in/IN
#   (NP a/DT huge/JJ oil/NN)
#   (NP field/NN)
#   majority-owned/JJ
#   by/IN
#   Abu/NNP
#   Dhabi/NNP
#   National/NNP
#   Oil/NNP
#   Co/NNP
#   ./.
#   In/IN
#   its/PRP$
#   (NP press/NN)
#   releases/NNS
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   billed/VBD
#   many/JJ
#   of/IN
#   these/DT
#   ventures/NNS
#   as/IN
#   Belt/NNP
#   and/CC
#   Road/NNP
#   deals/NNS
#   ,/,
#   further/RB
#   aligning/VBG
#   itself/PRP
#   with/IN
#   (NP the/DT Chinese/JJ government/NN)
#   ./.
#   ``/``
#   There/EX
#   is/VBZ
#   (NP no/DT type/NN)
#   of/IN
#   (NP project/NN)
#   that/WDT
#   does/VBZ
#   n't/RB
#   qualify/VB
#   as/IN
#   Belt/NNP
#   and/CC
#   Road/NNP
#   ,/,
#   and/CC
#   (NP no/DT continent/NN)
#   on/IN
#   (NP the/DT planet/NN)
#   that/WDT
#   does/VBZ
#   n't/RB
#   have/VB
#   Belt/NNP
#   and/CC
#   Road/NNP
#   ,/,
#   ''/''
#   says/VBZ
#   Christopher/NNP
#   Balding/NNP
#   ,/,
#   (NP an/DT associate/NN)
#   (NP professor/NN)
#   at/IN
#   the/DT
#   Fulbright/NNP
#   University/NNP
#   Vietnam/NNP
#   ./.
#   Due/NNP
#   to/TO
#   tight/VB
#   (NP capital/NN)
#   controls/NNS
#   ,/,
#   Chinese/JJ
#   companies/NNS
#   struggle/VBP
#   to/TO
#   move/VB
#   (NP money/NN)
#   abroad/RB
#   ,/,
#   he/PRP
#   explains/VBZ
#   ./.
#   Calling/VBG
#   deals/NNS
#   “/NNP
#   Belt/NNP
#   and/CC
#   Road/NNP
#   ”/NNP
#   projects/NNS
#   helps/VBP
#   companies/NNS
#   gain/VBP
#   (NP the/DT support/NN)
#   of/IN
#   (NP the/DT Chinese/JJ government/NN)
#   to/TO
#   do/VB
#   (NP business/NN)
#   internationally/RB
#   and/CC
#   move/VB
#   (NP money/NN)
#   out/IN
#   of/IN
#   China/NNP
#   ,/,
#   adds/VBZ
#   Balding/NNP
#   ./.
#   (NP “/NN)
#   There/EX
#   is/VBZ
#   (NP no/DT type/NN)
#   of/IN
#   (NP project/NN)
#   that/WDT
#   does/VBZ
#   n't/RB
#   qualify/VB
#   as/IN
#   Belt/NNP
#   and/CC
#   Road/NNP
#   ,/,
#   and/CC
#   (NP no/DT continent/NN)
#   on/IN
#   (NP the/DT planet/NN)
#   that/WDT
#   does/VBZ
#   n't/RB
#   have/VB
#   Belt/NNP
#   and/CC
#   Road/NNP
#   ”/NNP
#   Christopher/NNP
#   Balding/NNP
#   ,/,
#   (NP an/DT associate/NN)
#   (NP professor/NN)
#   at/IN
#   the/DT
#   Fulbright/NNP
#   University/NNP
#   Vietnam/NNP
#   In/IN
#   September/NNP
#   2017/CD
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   announced/VBD
#   its/PRP$
#   most/RBS
#   (NP high-profile/JJ investment/NN)
#   yet/RB
#   ./.
#   (NP The/DT company/NN)
#   was/VBD
#   to/TO
#   buy/VB
#   a/DT
#   14/CD
#   (NP %/NN)
#   (NP stake/NN)
#   in/IN
#   (NP Russian/JJ oil/NN)
#   (NP giant/NN)
#   Rosneft/NNP
#   for/IN
#   $/$
#   9/CD
#   billion/CD
#   --/:
#   (NP the/DT sort/NN)
#   of/IN
#   (NP super/JJ spend/NN)
#   usually/RB
#   reserved/VBN
#   for/IN
#   (NP a/DT state-owned/JJ company/NN)
#   ./.
#   That/DT
#   raised/VBD
#   eyebrows/NNS
#   ,/,
#   says/VBZ
#   Laban/NNP
#   Yu/NNP
#   ,/,
#   at/IN
#   the/DT
#   Jefferies/NNP
#   Group/NNP
#   (NP investment/NN)
#   (NP bank/NN)
#   ./.
#   ``/``
#   I/PRP
#   thought/VBD
#   ,/,
#   who/WP
#   would/MD
#   give/VB
#   them/PRP
#   (NP that/DT kind/NN)
#   of/IN
#   (NP money/NN)
#   ?/.
#   ''/''
#   (NP The/DT empire/NN)
#   falls/VBZ
#   Film/NNP
#   (NP star/NN)
#   Jackie/NNP
#   Chan/NNP
#   (/(
#   left/VBN
#   )/)
#   and/CC
#   the/DT
#   then/RB
#   Hong/NNP
#   Kong/NNP
#   Home/NNP
#   Affairs/NNP
#   (NP secretary/NN)
#   Patrick/NNP
#   Ho/NNP
#   at/IN
#   (NP an/DT event/NN)
#   raising/VBG
#   (NP money/NN)
#   for/IN
#   the/DT
#   Jackie/NNP
#   Chan/NNP
#   Charitable/NNP
#   (NP foundation/NN)
#   ,/,
#   the/DT
#   United/NNP
#   Nations/NNPS
#   Children/NNP
#   's/POS
#   (NP Fund/NN)
#   and/CC
#   the/DT
#   Community/NNP
#   Chest/NNP
#   ./.
#   Samantha/NNP
#   Sin/AFP/Getty/NNP
#   Images/NNP
#   Ye/NNP
#   ’/NNP
#   s/VBD
#   (NP empire/NN)
#   began/VBD
#   to/TO
#   crumble/VB
#   on/IN
#   November/NNP
#   18/CD
#   ,/,
#   2017/CD
#   ./.
#   On/IN
#   (NP that/DT day/NN)
#   ,/,
#   FBI/NNP
#   agents/NNS
#   arrested/VBD
#   Patrick/NNP
#   Ho/NNP
#   Chi-ping/NNP
#   ,/,
#   (NP the/DT man/NN)
#   Ye/NNP
#   had/VBD
#   employed/VBN
#   to/TO
#   lead/VB
#   his/PRP$
#   NGO/NNP
#   ./.
#   Ho/NNP
#   was/VBD
#   charged/VBN
#   with/IN
#   (NP money/NN)
#   (NP laundering/NN)
#   and/CC
#   violating/VBG
#   the/DT
#   Foreign/NNP
#   Corrupt/NNP
#   Practices/NNP
#   Act/NNP
#   ./.
#   He/PRP
#   is/VBZ
#   accused/VBN
#   of/IN
#   offering/VBG
#   $/$
#   3/CD
#   million/CD
#   in/IN
#   bribes/NNS
#   to/TO
#   the/DT
#   President/NNP
#   of/IN
#   Chad/NNP
#   ,/,
#   Idriss/NNP
#   Deby/NNP
#   ,/,
#   and/CC
#   Sam/NNP
#   Kutesa/NNP
#   ,/,
#   the/DT
#   Ugandan/NNP
#   (NP minister/NN)
#   of/IN
#   foreign/JJ
#   affairs/NNS
#   and/CC
#   then/RB
#   (NP president/NN)
#   of/IN
#   the/DT
#   United/NNP
#   Nations/NNP
#   General/NNP
#   Assembly/NNP
#   ./.
#   The/DT
#   alleged/JJ
#   bribes/NNS
#   were/VBD
#   made/VBN
#   on/IN
#   (NP behalf/NN)
#   of/IN
#   (NP a/DT Shanghai-based/JJ energy/NN)
#   (NP company/NN)
#   ,/,
#   which/WDT
#   is/VBZ
#   not/RB
#   explicitly/RB
#   named/VBN
#   in/IN
#   (NP the/DT court/NN)
#   documents/NNS
#   ./.
#   CNN/NNP
#   emails/NNS
#   and/CC
#   calls/VBZ
#   to/TO
#   (NP the/DT government/NN)
#   of/IN
#   Chad/NNP
#   went/VBD
#   unanswered/JJ
#   ./.
#   (NP Last/JJ year/NN)
#   ,/,
#   (NP the/DT government/NN)
#   of/IN
#   Chad/NNP
#   said/VBD
#   in/IN
#   (NP a/DT statement/NN)
#   :/:
#   ``/``
#   Faced/VBD
#   with/IN
#   (NP this/DT umpteenth/JJ false/JJ allegation/NN)
#   ,/,
#   (NP the/DT government/NN)
#   of/IN
#   Chad/NNP
#   formally/RB
#   refutes/VBZ
#   (NP this/DT shameful/JJ fabrication/NN)
#   ./.
#   ''/''
#   (NP The/DT government/NN)
#   of/IN
#   Uganda/NNP
#   has/VBZ
#   said/VBD
#   in/IN
#   (NP a/DT statement/NN)
#   that/IN
#   it/PRP
#   was/VBD
#   ``/``
#   erroneous/JJ
#   ''/''
#   to/TO
#   say/VB
#   Kutesa/NNP
#   was/VBD
#   involved/VBN
#   with/IN
#   the/DT
#   alleged/VBN
#   (NP bribery/NN)
#   ./.
#   Ho/NNP
#   ’/NNP
#   s/VBD
#   (NP lawyer/NN)
#   declined/VBD
#   to/TO
#   comment/VB
#   ,/,
#   but/CC
#   his/PRP$
#   (NP client/NN)
#   has/VBZ
#   pleaded/VBN
#   not/RB
#   guilty/JJ
#   to/TO
#   the/DT
#   charges/NNS
#   against/IN
#   him/PRP
#   ./.
#   At/IN
#   times/NNS
#   ,/,
#   (NP court/NN)
#   documents/NNS
#   show/VBP
#   ,/,
#   some/DT
#   people/NNS
#   at/IN
#   the/DT
#   UN/NNP
#   treated/VBD
#   the/DT
#   NGO/NNP
#   as/IN
#   (NP an/DT arm/NN)
#   of/IN
#   (NP the/DT Chinese/JJ state/NN)
#   ./.
#   For/IN
#   (NP example/NN)
#   ,/,
#   according/VBG
#   to/TO
#   emails/NNS
#   presented/VBN
#   by/IN
#   prosecutors/NNS
#   ,/,
#   Ho/NNP
#   was/VBD
#   asked/VBN
#   by/IN
#   (NP an/DT associate/NN)
#   to/TO
#   ``/``
#   intervene/VB
#   with/IN
#   (NP the/DT Chinese/JJ state/NN)
#   ''/''
#   to/TO
#   provide/VB
#   Chad/NNP
#   with/IN
#   military/JJ
#   weapons/NNS
#   to/TO
#   fight/VB
#   Boko/NNP
#   Haram/NNP
#   ./.
#   In/IN
#   emails/NNS
#   with/IN
#   other/JJ
#   individuals/NNS
#   ,/,
#   Ho/NNP
#   also/RB
#   discusses/VBZ
#   passing/VBG
#   on/IN
#   arms/NNS
#   to/TO
#   Libya/NNP
#   and/CC
#   Qatar/NNP
#   and/CC
#   suggests/VBZ
#   that/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   could/MD
#   help/VB
#   (NP an/DT Iranian/JJ company/NN)
#   (NP move/NN)
#   sanctioned/VBD
#   (NP money/NN)
#   out/IN
#   of/IN
#   China/NNP
#   ,/,
#   according/VBG
#   to/TO
#   prosecutors/NNS
#   ./.
#   In/IN
#   (NP a/DT statement/NN)
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   distanced/VBD
#   itself/PRP
#   from/IN
#   the/DT
#   NGO/NNP
#   ,/,
#   saying/VBG
#   that/IN
#   (NP the/DT latter/NN)
#   was/VBD
#   ``/``
#   not/RB
#   involved/VBN
#   in/IN
#   any/DT
#   of/IN
#   the/DT
#   commercial/JJ
#   activities/NNS
#   of/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ./.
#   ''/''
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   said/VBD
#   it/PRP
#   conducted/VBD
#   its/PRP$
#   (NP business/NN)
#   activities/NNS
#   ``/``
#   in/IN
#   (NP strict/JJ accordance/NN)
#   with/IN
#   (NP the/DT law/NN)
#   ./.
#   ''/''
#   (NP A/DT house/NN)
#   of/IN
#   cards/NNS
#   In/IN
#   (NP the/DT end/NN)
#   ,/,
#   (NP no/DT one/NN)
#   gave/VBD
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   the/DT
#   $/$
#   9/CD
#   billion/CD
#   to/TO
#   buy/VB
#   (NP the/DT stake/NN)
#   in/IN
#   Rosneft/NNP
#   ./.
#   Two/CD
#   months/NNS
#   after/IN
#   (NP the/DT deal/NN)
#   was/VBD
#   announced/VBN
#   ,/,
#   Ho/NNP
#   was/VBD
#   arrested/VBN
#   ./.
#   It/PRP
#   was/VBD
#   the/DT
#   falling/VBG
#   (NP domino/NN)
#   that/WDT
#   would/MD
#   bring/VB
#   down/RP
#   Ye/NNP
#   ’/NNP
#   (NP s/NN)
#   (NP empire/NN)
#   ./.
#   On/IN
#   March/NNP
#   1/CD
#   (NP this/DT year/NN)
#   ,/,
#   respected/VBD
#   (NP Chinese/JJ financial/JJ news/NN)
#   (NP outlet/NN)
#   ,/,
#   Caixin/NNP
#   ,/,
#   published/VBD
#   (NP an/DT explosive/JJ forensic/JJ investigation/NN)
#   into/IN
#   the/DT
#   finances/NNS
#   of/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ,/,
#   alleging/VBG
#   that/IN
#   (NP the/DT organization/NN)
#   was/VBD
#   (NP a/DT house/NN)
#   of/IN
#   cards/NNS
#   ,/,
#   precariously/RB
#   stacked/VBN
#   on/IN
#   loans/NNS
#   to/TO
#   cover/VB
#   loans/NNS
#   ./.
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   said/VBD
#   (NP the/DT report/NN)
#   ``/``
#   had/VBD
#   (NP no/DT basis/NN)
#   in/IN
#   (NP fact/NN)
#   ./.
#   ''/''
#   Days/VBZ
#   later/RB
#   ,/,
#   Ye/NNP
#   was/VBD
#   reportedly/RB
#   detained/VBN
#   in/IN
#   China/NNP
#   --/:
#   and/CC
#   he/PRP
#   has/VBZ
#   not/RB
#   been/VBN
#   seen/VBN
#   since/IN
#   ./.
#   (NP Industry/NN)
#   analysts/NNS
#   say/VBP
#   there/EX
#   had/VBD
#   long/RB
#   been/VBN
#   whispers/NNS
#   about/IN
#   (NP the/DT stability/NN)
#   of/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ,/,
#   with/IN
#   experts/NNS
#   believing/VBG
#   (NP the/DT company/NN)
#   did/VBD
#   not/RB
#   have/VB
#   enough/RB
#   (NP business/NN)
#   to/TO
#   match/VB
#   its/PRP$
#   (NP size/NN)
#   ./.
#   (NP The/DT entire/JJ floor/NN)
#   where/WRB
#   one/CD
#   CEFC/NNP
#   (NP branch/NN)
#   is/VBZ
#   registered/VBN
#   at/IN
#   is/VBZ
#   empty/JJ
#   ./.
#   (NP The/DT management/NN)
#   said/VBD
#   it/PRP
#   had/VBD
#   never/RB
#   been/VBN
#   occupied/VBN
#   ./.
#   CNN/NNP
#   One/NNP
#   (NP address/NN)
#   of/IN
#   three/CD
#   registered/VBD
#   CEFC/NNP
#   related/JJ
#   companies/NNS
#   is/VBZ
#   (NP a/DT defunct/JJ office/NN)
#   ./.
#   CNN/NNP
#   ``/``
#   Accounting/NNP
#   standards/NNS
#   and/CC
#   (NP corporate/JJ oversight/NN)
#   is/VBZ
#   still/RB
#   pretty/JJ
#   weak/JJ
#   in/IN
#   China/NNP
#   and/CC
#   there/EX
#   is/VBZ
#   n't/RB
#   (NP a/DT lot/NN)
#   of/IN
#   (NP transparency/NN)
#   ,/,
#   ''/''
#   says/VBZ
#   Tom/NNP
#   Rafferty/NNP
#   ,/,
#   a/DT
#   China/NNP
#   (NP expert/NN)
#   at/IN
#   the/DT
#   Economist/NNP
#   Intelligence/NNP
#   Unit/NNP
#   ./.
#   ``/``
#   There/EX
#   are/VBP
#   lots/NNS
#   of/IN
#   issues/NNS
#   in/IN
#   China/NNP
#   around/IN
#   opaque/JJ
#   corporate/JJ
#   structures/NNS
#   ./.
#   ''/''
#   CNN/NNP
#   contacted/VBD
#   China/NNP
#   ’/NNP
#   s/VBD
#   Ministry/NNP
#   of/IN
#   Foreign/NNP
#   Affairs/NNPS
#   about/IN
#   (NP the/DT relationship/NN)
#   between/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   and/CC
#   (NP the/DT Chinese/JJ government/NN)
#   ,/,
#   Ho/NNP
#   ’/NNP
#   (NP s/NN)
#   (NP arrest/NN)
#   in/IN
#   New/NNP
#   York/NNP
#   and/CC
#   the/DT
#   reports/NNS
#   that/IN
#   Ye/NNP
#   has/VBZ
#   been/VBN
#   detained/VBN
#   by/IN
#   the/DT
#   Chinese/JJ
#   authorities/NNS
#   ./.
#   (NP A/DT spokesperson/NN)
#   faxed/VBD
#   back/RP
#   (NP the/DT following/JJ response/NN)
#   :/:
#   (NP “/NN)
#   I/PRP
#   have/VBP
#   (NP no/DT knowledge/NN)
#   about/IN
#   (NP the/DT incident/NN)
#   you/PRP
#   mentioned/VBD
#   ./.
#   What/WP
#   I/PRP
#   can/MD
#   tell/VB
#   you/PRP
#   is/VBZ
#   ,/,
#   China/NNP
#   is/VBZ
#   (NP a/DT country/NN)
#   ruled/VBN
#   by/IN
#   (NP law/NN)
#   ,/,
#   and/CC
#   (NP the/DT Chinese/JJ government/NN)
#   has/VBZ
#   consistently/RB
#   asked/VBN
#   Chinese/JJ
#   enterprises/NNS
#   to/TO
#   abide/VB
#   by/IN
#   (NP local/JJ law/NN)
#   and/CC
#   regulations/NNS
#   when/WRB
#   they/PRP
#   operate/VBP
#   (NP overseas./JJ ”/NN)
#   Attempts/NNP
#   to/TO
#   reach/VB
#   Ye/NNP
#   for/IN
#   (NP comment/NN)
#   through/IN
#   his/PRP$
#   (NP company/NN)
#   were/VBD
#   unsuccessful/JJ
#   ./.
#   In/IN
#   Shanghai/NNP
#   ,/,
#   CNN/NNP
#   visited/VBD
#   the/DT
#   registered/JJ
#   addresses/NNS
#   of/IN
#   eight/CD
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   (NP subsidiary/NN)
#   companies/NNS
#   ./.
#   (NP None/NN)
#   showed/VBD
#   (NP any/DT sign/NN)
#   of/IN
#   (NP the/DT company/NN)
#   ./.
#   Two/CD
#   locations/NNS
#   were/VBD
#   (NP new/JJ office/NN)
#   buildings/NNS
#   which/WDT
#   had/VBD
#   never/RB
#   been/VBN
#   rented/VBN
#   out/RP
#   ,/,
#   while/IN
#   one/CD
#   was/VBD
#   (NP a/DT state-owned/JJ bank/NN)
#   ./.
#   At/IN
#   one/CD
#   (NP near-empty/JJ building/NN)
#   ,/,
#   (NP a/DT sign/NN)
#   carried/VBD
#   a/DT
#   President/NNP
#   Xi/NNP
#   (NP quote/NN)
#   :/:
#   ``/``
#   China/NNP
#   's/POS
#   (NP door/NN)
#   to/TO
#   (NP the/DT world/NN)
#   will/MD
#   never/RB
#   close/VB
#   ,/,
#   but/CC
#   only/RB
#   (NP open/JJ wider/NN)
#   ./.
#   ''/''
#   CEFC/NNP
#   is/VBZ
#   finally/RB
#   state-owned/JJ
#   Once/IN
#   (NP a/DT big/JJ buyer/NN)
#   ,/,
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   is/VBZ
#   now/RB
#   (NP a/DT big/JJ seller/NN)
#   --/:
#   its/PRP$
#   (NP property/NN)
#   is/VBZ
#   under/IN
#   (NP the/DT hammer/NN)
#   ,/,
#   with/IN
#   (NP a/DT Chinese/JJ state-owned/JJ company/NN)
#   taking/VBG
#   (NP control/NN)
#   of/IN
#   many/JJ
#   of/IN
#   its/PRP$
#   international/JJ
#   assets/NNS
#   ./.
#   Ye/NNP
#   ’/NNP
#   s/VBD
#   former/JJ
#   Bel/NNP
#   Air/NNP
#   (NP mansion/NN)
#   in/IN
#   Pok/NNP
#   Fu/NNP
#   Lam/NNP
#   ,/,
#   Hong/NNP
#   Kong/NNP
#   ./.
#   Savills/NNP
#   Ye/NNP
#   Jianming/NNP
#   bought/VBD
#   (NP a/DT two-bedroom/JJ apartment/NN)
#   overlooking/VBG
#   the/DT
#   United/NNP
#   Nations/NNPS
#   ./.
#   Newscom/NNP
#   In/IN
#   March/NNP
#   ,/,
#   (NP the/DT Czech/JJ government/NN)
#   sent/VBD
#   (NP a/DT delegation/NN)
#   to/TO
#   Beijing/NNP
#   to/TO
#   find/VB
#   out/RP
#   where/WRB
#   Ye/NNP
#   had/VBD
#   gone/VBN
#   ./.
#   Czech/NNP
#   President/NNP
#   Zeman/NNP
#   said/VBD
#   that/IN
#   Ye/NNP
#   ,/,
#   who/WP
#   is/VBZ
#   still/RB
#   his/PRP$
#   (NP economic/JJ adviser/NN)
#   ,/,
#   was/VBD
#   being/VBG
#   investigated/VBN
#   in/IN
#   China/NNP
#   on/IN
#   ``/``
#   (NP suspicion/NN)
#   of/IN
#   breaking/VBG
#   (NP the/DT law/NN)
#   ./.
#   ''/''
#   Zeman/NNP
#   ’/NNP
#   s/VBD
#   (NP spokesman/NN)
#   tells/NNS
#   CNN/NNP
#   that/IN
#   if/IN
#   Ye/NNP
#   “/NNP
#   is/VBZ
#   found/VBN
#   guilty/JJ
#   he/PRP
#   will/MD
#   cease/VB
#   to/TO
#   be/VB
#   (NP an/DT adviser/NN)
#   to/TO
#   Zeman/NNP
#   ./.
#   ''/''
#   Ye/NNP
#   's/POS
#   (NP downfall/NN)
#   comes/VBZ
#   amid/IN
#   (NP a/DT wider/NN)
#   (NP crackdown/NN)
#   in/IN
#   China/NNP
#   on/IN
#   debt-ridden/JJ
#   private/JJ
#   companies/NNS
#   ./.
#   Earlier/RBR
#   (NP this/DT year/NN)
#   ,/,
#   Wu/NNP
#   Xiaohui/NNP
#   ,/,
#   (NP chairman/NN)
#   of/IN
#   Anbang/NNP
#   Insurance/NNP
#   Group/NNP
#   ,/,
#   which/WDT
#   famously/RB
#   bought/VBD
#   New/NNP
#   York/NNP
#   ’/NNP
#   s/JJ
#   Waldorf/NNP
#   Hotel/NNP
#   for/IN
#   $/$
#   1.95/CD
#   billion/CD
#   ,/,
#   was/VBD
#   arrested/VBN
#   for/IN
#   fraudulently/RB
#   raising/VBG
#   billions/NNS
#   of/IN
#   dollars/NNS
#   from/IN
#   investors/NNS
#   ./.
#   In/IN
#   May/NNP
#   ,/,
#   he/PRP
#   was/VBD
#   sentenced/VBN
#   to/TO
#   18/CD
#   years/NNS
#   in/IN
#   (NP jail/NN)
#   by/IN
#   a/DT
#   Shanghai/NNP
#   (NP court/NN)
#   ./.
#   “/VB
#   (NP The/DT government/NN)
#   is/VBZ
#   n't/RB
#   happy/JJ
#   about/IN
#   how/WRB
#   they/PRP
#   've/VBP
#   been/VBN
#   conducting/VBG
#   their/PRP$
#   affairs/NNS
#   ,/,
#   particularly/RB
#   if/IN
#   they/PRP
#   've/VBP
#   been/VBN
#   using/VBG
#   it/PRP
#   to/TO
#   move/VB
#   their/PRP$
#   (NP capital/NN)
#   out/IN
#   of/IN
#   (NP the/DT country/NN)
#   ”/NNP
#   Tom/NNP
#   Rafferty/NNP
#   ,/,
#   (NP principal/JJ economist/NN)
#   for/IN
#   China/NNP
#   at/IN
#   the/DT
#   Economist/NNP
#   Intelligence/NNP
#   Unit/NNP
#   ``/``
#   (NP The/DT government/NN)
#   is/VBZ
#   n't/RB
#   happy/JJ
#   about/IN
#   how/WRB
#   they/PRP
#   've/VBP
#   been/VBN
#   conducting/VBG
#   their/PRP$
#   affairs/NNS
#   ,/,
#   particularly/RB
#   if/IN
#   they/PRP
#   've/VBP
#   been/VBN
#   using/VBG
#   it/PRP
#   to/TO
#   move/VB
#   their/PRP$
#   (NP capital/NN)
#   out/IN
#   of/IN
#   (NP the/DT country/NN)
#   ,/,
#   ''/''
#   says/VBZ
#   Rafferty/NNP
#   ,/,
#   of/IN
#   the/DT
#   Economist/NNP
#   Intelligence/NNP
#   Unit/NNP
#   ,/,
#   regarding/VBG
#   over-leveraged/JJ
#   companies/NNS
#   ./.
#   Two/CD
#   thirds/NNS
#   of/IN
#   (NP the/DT company/NN)
#   ’/NNP
#   (NP s/NN)
#   (NP financing/NN)
#   came/VBD
#   from/IN
#   the/DT
#   state-owned/JJ
#   China/NNP
#   Development/NNP
#   Bank/NNP
#   ./.
#   Today/NNP
#   ,/,
#   Chinese/NNP
#   state-owned/VBD
#   giant/JJ
#   CITIC/NNP
#   has/VBZ
#   taken/VBN
#   (NP control/NN)
#   of/IN
#   CEFC/NNP
#   China/NNP
#   Energy/NNP
#   ’/NNP
#   s/VBZ
#   Czech/NNP
#   assets/NNS
#   ./.
#   It/PRP
#   's/VBZ
#   (NP an/DT echo/NN)
#   of/IN
#   an/DT
#   earlier/JJR
#   Belt/NNP
#   and/CC
#   Road/NNP
#   (NP deal/NN)
#   gone/VBN
#   wrong/JJ
#   ,/,
#   in/IN
#   which/WDT
#   (NP the/DT Chinese/JJ government/NN)
#   took/VBD
#   (NP control/NN)
#   of/IN
#   (NP a/DT port/NN)
#   in/IN
#   Sri/NNP
#   Lanka/NNP
#   when/WRB
#   debts/NNS
#   to/TO
#   (NP a/DT Chinese/JJ state-owned/JJ bank/NN)
#   could/MD
#   n't/RB
#   be/VB
#   repaid/VBN
#   in/IN
#   2017/CD
#   ./.
#   Meanwhile/RB
#   ,/,
#   the/DT
#   whereabouts/NNS
#   of/IN
#   Ye/NNP
#   are/VBP
#   unknown/JJ
#   --/:
#   and/CC
#   what/WP
#   charges/NNS
#   ,/,
#   if/IN
#   any/DT
#   ,/,
#   he/PRP
#   may/MD
#   face/VB
#   in/IN
#   China/NNP
#   have/VBP
#   not/RB
#   been/VBN
#   publicly/RB
#   revealed/VBN
#   ./.)

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   The/DT
#   rise/NN
#   and/CC
#   fall/NN
#   of/IN
#   a/DT
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (GPE Road/NNP)
#   billionaire/NN
#   By/IN
#   (PERSON Jenni/NNP Marsh/NNP)
#   ,/,
#   (ORGANIZATION CNN/NNP Photo/NNP)
#   illustration/AP/NN
#   Images/NNP
#   In/IN
#   the/DT
#   mid-1990s/NNS
#   ,/,
#   (PERSON Ye/NNP Jianming/NNP)
#   had/VBD
#   a/DT
#   simple/JJ
#   job/NN
#   in/IN
#   a/DT
#   forest/NN
#   ,/,
#   or/CC
#   so/RB
#   his/PRP$
#   story/NN
#   goes/VBZ
#   ./.
#   Twenty/CD
#   years/NNS
#   later/RB
#   ,/,
#   he/PRP
#   sat/VBD
#   atop/VB
#   a/DT
#   $/$
#   44/CD
#   billion/CD
#   business/NN
#   empire/NN
#   ./.
#   Today/NN
#   ,/,
#   he/PRP
#   has/VBZ
#   vanished/VBN
#   and/CC
#   ,/,
#   as/IN
#   that/DT
#   empire/NN
#   crumbles/NNS
#   ,/,
#   is/VBZ
#   reportedly/RB
#   under/IN
#   investigation/NN
#   by/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ./.
#   How/WRB
#   all/DT
#   that/DT
#   happened/VBD
#   remains/VBZ
#   largely/RB
#   unknown/JJ
#   ./.
#   But/CC
#   one/CD
#   thing/NN
#   is/VBZ
#   clear/JJ
#   :/:
#   at/IN
#   its/PRP$
#   height/NN
#   ,/,
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/VBD
#   company/NN
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ,/,
#   aligned/VBD
#   itself/PRP
#   so/RB
#   closely/RB
#   with/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   that/IN
#   it/PRP
#   was/VBD
#   often/RB
#   hard/JJ
#   to/TO
#   distinguish/VB
#   between/IN
#   the/DT
#   two/CD
#   ./.
#   The/DT
#   young/JJ
#   tycoon/NN
#   appeared/VBD
#   to/TO
#   be/VB
#   (GPE China/NNP)
#   's/POS
#   unofficial/JJ
#   energy/NN
#   envoy/NN
#   ,/,
#   meeting/NN
#   presidents/NNS
#   across/IN
#   the/DT
#   globe/NN
#   and/CC
#   even/RB
#   becoming/VBG
#   an/DT
#   adviser/NN
#   to/TO
#   a/DT
#   (GPE European/JJ)
#   government/NN
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   he/PRP
#   ranked/VBD
#   No/NNP
#   ./.
#   2/CD
#   on/IN
#   the/DT
#   (ORGANIZATION Fortune/NNP)
#   magazine/NN
#   40/CD
#   Under/IN
#   40/CD
#   list/NN
#   ./.
#   But/CC
#   last/JJ
#   November/NNP
#   ,/,
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/VBD
#   seemingly/RB
#   unstoppable/JJ
#   rise/NN
#   came/VBD
#   to/TO
#   a/DT
#   screeching/JJ
#   halt/NN
#   ./.
#   His/PRP$
#   undoing/NN
#   came/VBD
#   after/IN
#   (GSP US/NNP)
#   prosecutors/NNS
#   alleged/VBD
#   that/IN
#   an/DT
#   NGO/NNP
#   he/PRP
#   funded/VBD
#   had/VBD
#   used/VBN
#   its/PRP$
#   (ORGANIZATION United/NNP Nations/NNPS)
#   status/NN
#   to/TO
#   offer/VB
#   millions/NNS
#   in/IN
#   bribes/NN
#   to/TO
#   (GPE African/JJ)
#   leaders/NNS
#   ,/,
#   although/IN
#   he/PRP
#   is/VBZ
#   not/RB
#   charged/VBN
#   ./.
#   As/IN
#   that/DT
#   case/NN
#   plays/VBZ
#   out/RP
#   in/IN
#   a/DT
#   (GPE Manhattan/NNP)
#   courthouse/NN
#   ,/,
#   the/DT
#   world/NN
#   is/VBZ
#   offered/VBN
#   a/DT
#   rare/JJ
#   glimpse/NN
#   into/IN
#   the/DT
#   complex/JJ
#   relations/NNS
#   between/IN
#   private/JJ
#   business/NN
#   and/CC
#   the/DT
#   (GPE Chinese/JJ)
#   state/NN
#   --/:
#   and/CC
#   with/IN
#   it/PRP
#   ,/,
#   a/DT
#   cautionary/JJ
#   tale/NN
#   of/IN
#   what/WP
#   happens/VBZ
#   when/WRB
#   a/DT
#   (GPE Chinese/JJ)
#   company/NN
#   fails/VBZ
#   abroad/RB
#   ./.
#   (PERSON Czech/JJ)
#   invasion/NN
#   (PERSON Ye/NNP)
#   came/VBD
#   to/TO
#   international/JJ
#   prominence/NN
#   in/IN
#   the/DT
#   summer/NN
#   of/IN
#   2015/CD
#   ,/,
#   following/VBG
#   an/DT
#   extraordinary/JJ
#   buying/NN
#   spree/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Czech/NNP Republic/NNP)
#   ./.
#   As/IN
#   the/DT
#   chairman/NN
#   of/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ,/,
#   (PERSON Ye/NNP)
#   snapped/VBD
#   up/RP
#   the/DT
#   country/NN
#   's/POS
#   oldest/JJS
#   football/NN
#   club/NN
#   ,/,
#   (PERSON Slavia/NNP Praha/NNP)
#   ;/:
#   a/DT
#   brewery/NN
#   ;/:
#   a/DT
#   share/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Travel/NNP Service/NNP)
#   airline/NN
#   group/NN
#   ;/:
#   a/DT
#   publishing/NN
#   house/NN
#   ;/:
#   a/DT
#   neo-renaissance/JJ
#   building/NN
#   ;/:
#   a/DT
#   stake/NN
#   in/IN
#   the/DT
#   investment/NN
#   bank/NN
#   J/NNP
#   &/CC
#   T/NNP
#   Finance/NNP
#   Group/NNP
#   ;/:
#   and/CC
#   a/DT
#   building/NN
#   in/IN
#   the/DT
#   (GPE Czech/NNP)
#   capital/NN
#   (PERSON Prague/NNP)
#   ,/,
#   intended/VBD
#   for/IN
#   use/NN
#   as/IN
#   the/DT
#   company/NN
#   's/POS
#   (GPE European/JJ)
#   headquarters/NN
#   ./.
#   A/DT
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   sign/NN
#   in/IN
#   (GPE Shanghai/NNP)
#   ,/,
#   (GPE China/NNP)
#   ./.
#   (ORGANIZATION Newscom/NNP Inside/IN the/DT Czech/NNP Republic/NNP)
#   ,/,
#   the/DT
#   acquisitions/NNS
#   were/VBD
#   greeted/VBN
#   with/IN
#   bemusement/NN
#   :/:
#   Why/WRB
#   would/MD
#   an/DT
#   energy/NN
#   company/NN
#   want/VBP
#   a/DT
#   brewery/NN
#   ?/.
#   And/CC
#   why/WRB
#   was/VBD
#   a/DT
#   (GPE Chinese/JJ)
#   company/NN
#   suddenly/RB
#   so/RB
#   welcome/JJ
#   in/IN
#   a/DT
#   country/NN
#   that/WDT
#   had/VBD
#   ,/,
#   until/IN
#   recently/RB
#   ,/,
#   been/VBN
#   hostile/JJ
#   to/TO
#   (GPE China/NNP)
#   ?/.
#   As/IN
#   with/IN
#   just/RB
#   about/IN
#   everything/NN
#   involving/VBG
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ,/,
#   the/DT
#   answers/NNS
#   would/MD
#   eventually/RB
#   point/VB
#   to/TO
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ./.
#   From/IN
#   its/PRP$
#   founding/NN
#   in/IN
#   1993/CD
#   until/IN
#   2003/CD
#   ,/,
#   the/DT
#   (ORGANIZATION Czech/NNP Republic/NNP)
#   was/VBD
#   led/VBN
#   by/IN
#   (PERSON Vaclav/NNP Havel/NNP)
#   ,/,
#   a/DT
#   dissident/NN
#   turned/VBD
#   elected/JJ
#   politician/NN
#   ,/,
#   whose/WP$
#   impassioned/JJ
#   campaigning/NN
#   had/VBD
#   helped/VBN
#   topple/VB
#   the/DT
#   country/NN
#   's/POS
#   former/JJ
#   communist/JJ
#   government/NN
#   and/CC
#   usher/NN
#   in/IN
#   a/DT
#   new/JJ
#   era/NN
#   of/IN
#   democracy/NN
#   ./.
#   Throughout/IN
#   his/PRP$
#   decade/NN
#   in/IN
#   office/NN
#   ,/,
#   (PERSON Havel/NNP)
#   made/VBD
#   no/DT
#   attempt/NN
#   to/TO
#   hide/VB
#   his/PRP$
#   disdain/NN
#   for/IN
#   (GPE China/NNP)
#   's/POS
#   own/JJ
#   communist/NN
#   rulers/NNS
#   ,/,
#   regularly/RB
#   meeting/VBG
#   with/IN
#   the/DT
#   (PERSON Dalai/NNP Lama/NNP)
#   --/:
#   who/WP
#   is/VBZ
#   considered/VBN
#   by/IN
#   (GPE China/NNP)
#   to/TO
#   be/VB
#   a/DT
#   dangerous/JJ
#   separatist/NN
#   ./.
#   Relations/NNS
#   changed/VBD
#   with/IN
#   the/DT
#   election/NN
#   of/IN
#   (PERSON Milos/NNP Zeman/NNP)
#   to/TO
#   the/DT
#   top/JJ
#   office/NN
#   in/IN
#   2013/CD
#   ./.
#   Touted/VBN
#   as/IN
#   the/DT
#   (ORGANIZATION Czech/NNP Republic/NNP)
#   's/POS
#   first/JJ
#   China-friendly/JJ
#   president/NN
#   ,/,
#   (PERSON Zeman/NNP)
#   was/VBD
#   keen/JJ
#   to/TO
#   facilitate/VB
#   increased/VBN
#   trade/NN
#   between/IN
#   (GPE Beijing/NNP)
#   and/CC
#   (GPE Prague/NNP)
#   ./.
#   The/DT
#   following/JJ
#   year/NN
#   ,/,
#   a/DT
#   (GPE Czech/JJ)
#   entity/NN
#   would/MD
#   become/VB
#   the/DT
#   first/JJ
#   wholly/RB
#   foreign-owned/JJ
#   company/NN
#   to/TO
#   provide/VB
#   loans/NNS
#   across/IN
#   (GPE China/NNP)
#   ,/,
#   a/DT
#   huge/JJ
#   coup/NN
#   in/IN
#   the/DT
#   country/NN
#   's/POS
#   relatively/RB
#   untapped/JJ
#   consumer/NN
#   credit/NN
#   market/NN
#   ./.
#   (PERSON Ye/NNP)
#   sensed/VBD
#   an/DT
#   opportunity/NN
#   ./.
#   He/PRP
#   was/VBD
#   quietly/RB
#   made/VBN
#   a/DT
#   special/JJ
#   economic/JJ
#   adviser/NN
#   to/TO
#   (PERSON Zeman/NNP)
#   ,/,
#   something/NN
#   that/WDT
#   would/MD
#   only/RB
#   be/VB
#   announced/VBN
#   six/CD
#   months/NNS
#   after/IN
#   the/DT
#   fact/NN
#   ./.
#   (PERSON Miroslav/NNP Kalousek/NNP)
#   ,/,
#   a/DT
#   (GPE Czech/JJ)
#   opposition/NN
#   MP/NNP
#   ,/,
#   says/VBZ
#   he/PRP
#   considers/VBZ
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/JJ
#   role/NN
#   in/IN
#   his/PRP$
#   country/NN
#   ’/NNP
#   s/JJ
#   government/NN
#   as/IN
#   ``/``
#   scandalous/JJ
#   and/CC
#   a/DT
#   security/NN
#   risk/NN
#   ./.
#   ''/''
#   Shortly/RB
#   after/IN
#   (PERSON Ye/NNP)
#   's/POS
#   appointment/NN
#   came/VBD
#   his/PRP$
#   high-profile/JJ
#   splurge/NN
#   ./.
#   The/DT
#   deals/NNS
#   made/VBD
#   no/DT
#   commercial/JJ
#   sense/NN
#   ,/,
#   says/VBZ
#   (PERSON Martin/NNP Hala/NNP)
#   ,/,
#   a/DT
#   leading/VBG
#   (GSP Czech/JJ)
#   academic/JJ
#   in/IN
#   (GPE Chinese/JJ)
#   studies/NNS
#   ./.
#   But/CC
#   they/PRP
#   sent/VBD
#   a/DT
#   clear/JJ
#   message/NN
#   from/IN
#   (GPE Beijing/NNP)
#   to/TO
#   the/DT
#   international/JJ
#   community/NN
#   that/IN
#   (GPE China/NNP)
#   now/RB
#   had/VBD
#   a/DT
#   firm/JJ
#   friend/NN
#   in/IN
#   (GPE Europe/NNP)
#   ./.
#   That/DT
#   was/VBD
#   important/JJ
#   ./.
#   (GPE Chinese/JJ)
#   President/NNP
#   (PERSON Xi/NNP Jinping/NNP)
#   's/POS
#   flagship/NN
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (GPE Road/NNP)
#   initiative/NN
#   aims/NNS
#   to/TO
#   export/VB
#   (GPE Chinese/NNP)
#   commerce/NN
#   ,/,
#   goods/NNS
#   and/CC
#   influence/NN
#   across/IN
#   the/DT
#   globe/NN
#   ./.
#   A/DT
#   foothold/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Czech/NNP Republic/NNP)
#   gave/VBD
#   (GPE China/NNP)
#   a/DT
#   gateway/NN
#   to/TO
#   (GPE Europe/NNP)
#   ,/,
#   and/CC
#   a/DT
#   valuable/JJ
#   political/JJ
#   ally/NN
#   within/IN
#   the/DT
#   (ORGANIZATION European/NNP Union/NNP)
#   ,/,
#   (GPE Beijing/NNP)
#   's/POS
#   largest/JJS
#   trading/NN
#   partner/NN
#   ./.
#   (GPE Chinese/JJ)
#   President/NNP
#   (PERSON Xi/NNP Jinping/NNP)
#   ,/,
#   second/NN
#   from/IN
#   right/NN
#   ,/,
#   with/IN
#   (PERSON Czech/NNP)
#   President/NNP
#   (PERSON Milos/NNP Zeman/NNP)
#   ,/,
#   third/JJ
#   from/IN
#   left/NN
#   ,/,
#   at/IN
#   the/DT
#   (FACILITY Great/NNP Hall/NNP)
#   of/IN
#   the/DT
#   People/NNP
#   in/IN
#   (GPE Beijing/NNP)
#   in/IN
#   September/NNP
#   ,/,
#   2015/CD
#   ./.
#   Ye/VB
#   Jianming/NNP
#   is/VBZ
#   on/IN
#   the/DT
#   far/RB
#   left/NN
#   ./.
#   (PERSON Lucie/NNP Mikolaskova/NNP)
#   (/(
#   (ORGANIZATION CTK/NNP)
#   via/IN
#   (ORGANIZATION AP/NNP Images/NNP)
#   )/)
#   (PERSON Stephen/NNP Platt/NNP)
#   ,/,
#   an/DT
#   (GPE American/JJ)
#   historian/NN
#   and/CC
#   professor/NN
#   of/IN
#   (GPE Chinese/JJ)
#   history/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Massachusetts/NNP Amherst/NNP)
#   ,/,
#   says/VBZ
#   there/EX
#   is/VBZ
#   a/DT
#   long/JJ
#   history/NN
#   of/IN
#   private/JJ
#   businessmen/NNS
#   advancing/VBG
#   the/DT
#   influence/NN
#   of/IN
#   their/PRP$
#   country/NN
#   abroad/RB
#   ,/,
#   dating/VBG
#   back/RB
#   to/TO
#   the/DT
#   (GPE British/JJ)
#   (LOCATION East/NNP India/NNP)
#   Company/NNP
#   and/CC
#   the/DT
#   cotton/NN
#   and/CC
#   silk/NN
#   traders/NNS
#   who/WP
#   sparked/VBD
#   the/DT
#   (ORGANIZATION Opium/NNP Wars/NNP)
#   in/IN
#   (GPE China/NNP)
#   ./.
#   ``/``
#   It/PRP
#   takes/VBZ
#   the/DT
#   risk/NN
#   and/CC
#   financial/JJ
#   burden/NN
#   off/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ,/,
#   ''/''
#   he/PRP
#   says/VBZ
#   ./.
#   ``/``
#   If/IN
#   the/DT
#   companies/NNS
#   go/VBP
#   bankrupt/VBP
#   that/DT
#   's/VBZ
#   their/PRP$
#   problem/NN
#   and/CC
#   (/(
#   in/IN
#   the/DT
#   meantime/NN
#   )/)
#   the/DT
#   government/NN
#   can/MD
#   take/VB
#   advantage/NN
#   of/IN
#   (/(
#   them/PRP
#   )/)
#   spreading/VBG
#   a/DT
#   positive/JJ
#   view/NN
#   of/IN
#   (GPE China/NNP)
#   and/CC
#   increasing/VBG
#   (GPE China/NNP)
#   's/POS
#   influence/NN
#   ./.
#   ''/''
#   When/WRB
#   (PERSON Zeman/NNP)
#   met/VBD
#   with/IN
#   (PERSON Xi/NNP Jinping/NNP)
#   in/IN
#   (GPE Beijing/NNP)
#   in/IN
#   2015/CD
#   ,/,
#   (PERSON Ye/NNP)
#   was/VBD
#   photographed/VBN
#   with/IN
#   both/DT
#   presidents/NNS
#   ./.
#   His/PRP$
#   proximity/NN
#   to/TO
#   the/DT
#   center/NN
#   of/IN
#   (GPE Chinese/JJ)
#   power/NN
#   had/VBD
#   never/RB
#   looked/VBN
#   stronger/JJR
#   ./.
#   No/DT
#   prince/NN
#   The/DT
#   (GSP Czech/JJ)
#   deals/NNS
#   caused/VBD
#   a/DT
#   buzz/NN
#   around/IN
#   (GPE Ye/NNP)
#   ./.
#   ``/``
#   Journalists/NNS
#   would/MD
#   be/VB
#   calling/VBG
#   me/PRP
#   up/IN
#   asking/VBG
#   :/:
#   'What/WP
#   do/VBP
#   you/PRP
#   know/VB
#   about/IN
#   this/DT
#   ?/.
#   '/''
#   ''/''
#   says/VBZ
#   (PERSON Laban/NNP Yu/NNP)
#   ,/,
#   the/DT
#   head/NN
#   of/IN
#   (GPE China/NNP)
#   research/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Jefferies/NNP Group/NNP)
#   investment/NN
#   bank/NN
#   ./.
#   He/PRP
#   would/MD
#   shrug/VB
#   ./.
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   “/NNP
#   came/VBD
#   out/RP
#   from/IN
#   nowhere/RB
#   ,/,
#   ”/NNP
#   says/VBZ
#   Yu/NNP
#   ./.
#   By/IN
#   2018/CD
#   ,/,
#   it/PRP
#   was/VBD
#   widely/RB
#   reported/VBN
#   that/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   had/VBD
#   a/DT
#   global/JJ
#   property/NN
#   portfolio/NN
#   worth/JJ
#   $/$
#   3.2/CD
#   billion/CD
#   ,/,
#   including/VBG
#   office/NN
#   space/NN
#   in/IN
#   central/JJ
#   (GPE Hong/NNP Kong/NNP)
#   and/CC
#   a/DT
#   (ORGANIZATION Trump/NNP)
#   World/NNP
#   Tower/NNP
#   apartment/NN
#   in/IN
#   (GPE Manhattan/NNP)
#   ./.
#   The/DT
#   company/NN
#   employed/VBD
#   nearly/RB
#   50,000/CD
#   people/NNS
#   ,/,
#   was/VBD
#   ranked/VBN
#   No/NNP
#   ./.
#   222/CD
#   on/IN
#   the/DT
#   2017/CD
#   Fortune/NNP
#   500/CD
#   list/NN
#   and/CC
#   in/IN
#   2015/CD
#   made/VBD
#   about/IN
#   $/$
#   40/CD
#   billion/CD
#   in/IN
#   revenue/NN
#   ./.
#   “/NN
#   (/(
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   )/)
#   came/VBD
#   out/RP
#   from/IN
#   nowhere/RB
#   ”/JJ
#   (PERSON Laban/NNP Yu/NNP)
#   ,/,
#   head/NN
#   of/IN
#   (GPE China/NNP)
#   research/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Jefferies/NNP Group/NNP)
#   In/IN
#   2016/CD
#   ,/,
#   (PERSON Ye/NNP)
#   granted/VBD
#   Fortune/NNP
#   magazine/NN
#   what/WP
#   remains/VBZ
#   his/PRP$
#   only/JJ
#   interview/NN
#   with/IN
#   (GSP Western/JJ)
#   media/NNS
#   ./.
#   It/PRP
#   was/VBD
#   an/DT
#   opportunity/NN
#   to/TO
#   address/VB
#   questions/NNS
#   of/IN
#   his/PRP$
#   alleged/JJ
#   government/NN
#   ties/NNS
#   ./.
#   For/IN
#   years/NNS
#   ,/,
#   rumors/NNS
#   had/VBD
#   circulated/VBN
#   in/IN
#   (GPE China/NNP)
#   that/IN
#   (PERSON Ye/NNP)
#   was/VBD
#   a/DT
#   People/NNP
#   ’/NNP
#   s/JJ
#   (ORGANIZATION Liberation/NNP Army/NNP)
#   (/(
#   (ORGANIZATION PLA/NNP)
#   )/)
#   princeling/NN
#   --/:
#   the/DT
#   name/NN
#   given/VBN
#   to/TO
#   offspring/VBG
#   of/IN
#   the/DT
#   founding/VBG
#   fathers/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION People/NNP)
#   's/POS
#   (ORGANIZATION Republic/NNP)
#   of/IN
#   (GPE China/NNP)
#   ,/,
#   who/WP
#   used/VBD
#   their/PRP$
#   power/NN
#   to/TO
#   amass/VB
#   vast/JJ
#   wealth/NN
#   ./.
#   Many/JJ
#   princelings/NNS
#   hold/VBP
#   top/JJ
#   positions/NNS
#   in/IN
#   state-owned/JJ
#   enterprises/NNS
#   (/(
#   (ORGANIZATION SOEs/NNP)
#   )/)
#   or/CC
#   are/VBP
#   high-ranking/JJ
#   politicians/NNS
#   ./.
#   President/NNP
#   (PERSON Xi/NNP)
#   ,/,
#   for/IN
#   instance/NN
#   ,/,
#   is/VBZ
#   the/DT
#   son/NN
#   a/DT
#   former/JJ
#   vice/NN
#   premier/NN
#   of/IN
#   the/DT
#   (ORGANIZATION State/NNP Council/NNP)
#   ./.
#   In/IN
#   (GPE China/NNP)
#   ,/,
#   princeling/VBG
#   status/NN
#   is/VBZ
#   often/RB
#   considered/VBN
#   the/DT
#   fastest/JJS
#   way/NN
#   to/TO
#   get/VB
#   rich/JJ
#   ./.
#   Onlookers/NNS
#   theorized/VBD
#   that/IN
#   (PERSON Ye/NNP Jianming/NNP)
#   's/POS
#   grandfather/NN
#   was/VBD
#   a/DT
#   high-ranking/JJ
#   (ORGANIZATION Communist/NNP Party/NNP)
#   official/NN
#   called/VBD
#   (PERSON Ye/NNP Jianying/NNP)
#   ./.
#   A/DT
#   biography/NN
#   of/IN
#   the/DT
#   younger/JJR
#   Ye/NNP
#   in/IN
#   a/DT
#   2012/CD
#   financial/JJ
#   report/NN
#   seemed/VBD
#   to/TO
#   support/VB
#   claims/NNS
#   of/IN
#   high-level/JJ
#   (ORGANIZATION PLA/NNP)
#   ties/NNS
#   ./.
#   It/PRP
#   states/VBZ
#   that/IN
#   from/IN
#   2003/CD
#   until/IN
#   2005/CD
#   he/PRP
#   was/VBD
#   the/DT
#   deputy/NN
#   secretary/NN
#   general/NN
#   of/IN
#   the/DT
#   (GPE China/NNP)
#   Association/NNP
#   for/IN
#   (ORGANIZATION International/NNP Friendly/NNP Contact/NNP)
#   (/(
#   (ORGANIZATION CAIFC/NNP)
#   )/)
#   ./.
#   That/DT
#   group/NN
#   is/VBZ
#   a/DT
#   purported/JJ
#   political/JJ
#   arm/NN
#   of/IN
#   the/DT
#   (GPE Chinese/JJ)
#   military/JJ
#   ,/,
#   according/VBG
#   to/TO
#   a/DT
#   report/NN
#   by/IN
#   the/DT
#   Project/NN
#   2049/CD
#   Institute/NNP
#   ,/,
#   a/DT
#   US-based/JJ
#   organization/NN
#   that/WDT
#   researches/VBZ
#   (GPE Asia/NNP)
#   security/NN
#   issues/NNS
#   ./.
#   Stylistic/JJ
#   similarities/NNS
#   between/IN
#   the/DT
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   and/CC
#   (ORGANIZATION CAIFC/NNP)
#   logos/VBP
#   did/VBD
#   nothing/NN
#   to/TO
#   dispel/VB
#   the/DT
#   idea/NN
#   that/IN
#   (PERSON Ye/NNP)
#   was/VBD
#   linked/VBN
#   to/TO
#   the/DT
#   military/JJ
#   ./.
#   In/IN
#   an/DT
#   email/NN
#   ,/,
#   (ORGANIZATION CAIFC/NNP)
#   denied/VBD
#   that/IN
#   (PERSON Ye/NNP Jianming/NNP)
#   had/VBD
#   been/VBN
#   deputy/JJ
#   chair/NN
#   of/IN
#   the/DT
#   organization/NN
#   and/CC
#   that/IN
#   it/PRP
#   had/VBD
#   military/JJ
#   ties/NNS
#   ./.
#   (ORGANIZATION CEFC/NNP)
#   ,/,
#   (ORGANIZATION CAIFC/NNP Ye/NNP)
#   wanted/VBD
#   people/NNS
#   to/TO
#   believe/VB
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   was/VBD
#   intimately/RB
#   related/VBN
#   to/TO
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   the/DT
#   (GPE Chinese/JJ)
#   state/NN
#   ,/,
#   says/VBZ
#   (PERSON Andrew/NNP Chubb/NNP)
#   ,/,
#   a/DT
#   postdoctoral/JJ
#   fellow/NN
#   in/IN
#   the/DT
#   Columbia-Harvard/NNP
#   (GPE China/NNP)
#   and/CC
#   the/DT
#   World/NNP
#   Program/NNP
#   ./.
#   But/CC
#   when/WRB
#   asked/VBD
#   about/IN
#   the/DT
#   issue/NN
#   ,/,
#   (PERSON Ye/NNP)
#   told/VBD
#   Fortune/NNP
#   he/PRP
#   didn/VBZ
#   ’/JJ
#   t/NNS
#   have/VBP
#   military/JJ
#   ties/NNS
#   ./.
#   From/IN
#   the/DT
#   yellow/JJ
#   stars/NNS
#   in/IN
#   its/PRP$
#   logo/NN
#   to/TO
#   the/DT
#   fact/NN
#   it/PRP
#   had/VBD
#   (GPE China/NNP)
#   in/IN
#   its/PRP$
#   name/NN
#   --/:
#   a/DT
#   privilege/NN
#   normally/RB
#   reserved/VBN
#   for/IN
#   state-owned/JJ
#   companies/NNS
#   --/:
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ’/NNP
#   s/VBD
#   messaging/VBG
#   strongly/RB
#   suggested/VBN
#   state/NN
#   ties/NNS
#   ./.
#   So/RB
#   why/WRB
#   was/VBD
#   Ye/NNP
#   denying/VBG
#   links/NNS
#   ?/.
#   “/NN
#   To/TO
#   me/PRP
#   ,/,
#   it/PRP
#   's/VBZ
#   a/DT
#   story/NN
#   of/IN
#   how/WRB
#   people/NNS
#   who/WP
#   are/VBP
#   really/RB
#   unimportant/JJ
#   can/MD
#   make/VB
#   things/NNS
#   happen/VB
#   ”/RB
#   (PERSON Bonnie/NNP Glaser/NNP)
#   ,/,
#   senior/JJ
#   adviser/NN
#   for/IN
#   the/DT
#   (ORGANIZATION Center/NNP)
#   for/IN
#   (PERSON Strategic/NNP)
#   and/CC
#   (ORGANIZATION International/NNP Studies/NNP)
#   Perhaps/RB
#   some/DT
#   of/IN
#   his/PRP$
#   ties/NNS
#   were/VBD
#   not/RB
#   that/IN
#   strong/JJ
#   ./.
#   (PERSON Bonnie/NNP Glaser/NNP)
#   ,/,
#   director/NN
#   of/IN
#   the/DT
#   (GPE China/NNP)
#   Power/NNP
#   Project/NNP
#   in/IN
#   (GPE Washington/NNP)
#   ,/,
#   says/VBZ
#   she/PRP
#   was/VBD
#   introduced/VBN
#   to/TO
#   Ye/VB
#   in/IN
#   2010/CD
#   ,/,
#   in/IN
#   (GPE Shanghai/NNP)
#   ,/,
#   through/IN
#   a/DT
#   (ORGANIZATION PLA/NNP)
#   admiral/NN
#   who/WP
#   was/VBD
#   writing/VBG
#   the/DT
#   proposal/NN
#   for/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   to/TO
#   set/VB
#   up/RP
#   an/DT
#   NGO/NN
#   at/IN
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNPS)
#   ./.
#   The/DT
#   admiral/NN
#   was/VBD
#   n't/RB
#   overly/RB
#   influential/JJ
#   or/CC
#   wealthy/JJ
#   ,/,
#   she/PRP
#   says/VBZ
#   ,/,
#   but/CC
#   spoke/VBD
#   good/JJ
#   (GPE English/NNP)
#   and/CC
#   knew/VBD
#   (GPE Western/JJ)
#   procedures/NNS
#   ./.
#   The/DT
#   following/JJ
#   year/NN
#   ,/,
#   (PERSON Ye/NNP)
#   's/POS
#   (ORGANIZATION NGO/NNP)
#   was/VBD
#   officially/RB
#   recognized/VBN
#   by/IN
#   the/DT
#   (ORGANIZATION UN/NNP)
#   ./.
#   ``/``
#   To/TO
#   me/PRP
#   ,/,
#   it/PRP
#   's/VBZ
#   a/DT
#   story/NN
#   of/IN
#   how/WRB
#   people/NNS
#   who/WP
#   are/VBP
#   really/RB
#   unimportant/JJ
#   can/MD
#   make/VB
#   things/NNS
#   happen/VB
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Glaser/NNP)
#   ,/,
#   who/WP
#   has/VBZ
#   advised/VBN
#   the/DT
#   (GPE US/NNP)
#   government/NN
#   on/IN
#   (GPE Chinese/JJ)
#   affairs/NNS
#   ./.
#   In/IN
#   his/PRP$
#   Fortune/NNP
#   interview/NN
#   ,/,
#   (PERSON Ye/NNP)
#   provided/VBD
#   an/DT
#   alternative/JJ
#   story/NN
#   to/TO
#   the/DT
#   (ORGANIZATION PLA/NNP)
#   princeling/NN
#   rumors/NNS
#   :/:
#   After/IN
#   a/DT
#   stint/NN
#   in/IN
#   the/DT
#   forest/JJS
#   police/NN
#   ,/,
#   while/IN
#   still/RB
#   in/IN
#   his/PRP$
#   early/JJ
#   20s/CD
#   ,/,
#   he/PRP
#   somehow/RB
#   managed/VBD
#   to/TO
#   buy/VB
#   oil/NN
#   assets/NNS
#   at/IN
#   auction/NN
#   from/IN
#   a/DT
#   businessman/NN
#   who/WP
#   had/VBD
#   fled/VBN
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/VBD
#   home/NN
#   province/NN
#   of/IN
#   (GPE Fujian/NNP)
#   in/IN
#   southern/JJ
#   (GPE China/NNP)
#   ./.
#   (PERSON Ye/NNP)
#   insisted/VBD
#   it/PRP
#   was/VBD
#   (GPE Hong/NNP Kong/NNP)
#   and/CC
#   (GPE Fujian/JJ)
#   businessmen/NNS
#   who/WP
#   gave/VBD
#   him/PRP
#   the/DT
#   cash/NN
#   ./.
#   “/NNS
#   But/CC
#   why/WRB
#   they/PRP
#   would/MD
#   put/VB
#   a/DT
#   20-something/JJ
#   in/IN
#   charge/NN
#   of/IN
#   that/DT
#   is/VBZ
#   totally/RB
#   mysterious/JJ
#   ,/,
#   ”/NNP
#   says/VBZ
#   (PERSON Chubb/NNP)
#   ./.
#   (GPE Chinese/JJ)
#   journalists/NNS
#   who/WP
#   subsequently/RB
#   traveled/VBD
#   to/TO
#   (PERSON Ye/NNP)
#   's/POS
#   parents/NNS
#   ’/VBP
#   home/NN
#   claimed/VBD
#   his/PRP$
#   family/NN
#   were/VBD
#   modest/JJ
#   fishermen/NNS
#   ./.
#   The/DT
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (PERSON Road/NNP)
#   On/IN
#   a/DT
#   quiet/JJ
#   ,/,
#   tree-lined/JJ
#   street/NN
#   in/IN
#   (GPE Shanghai/NNP)
#   's/POS
#   former/JJ
#   (GPE French/JJ)
#   (ORGANIZATION Concession/NNP)
#   district/NN
#   ,/,
#   amid/IN
#   the/DT
#   city/NN
#   's/POS
#   most/RBS
#   historic/JJ
#   and/CC
#   expensive/JJ
#   real/JJ
#   estate/NN
#   ,/,
#   lies/VBZ
#   the/DT
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   compound/NN
#   ./.
#   Designed/VBN
#   as/IN
#   a/DT
#   Western-style/JJ
#   palace/NN
#   ,/,
#   the/DT
#   compound/NN
#   features/VBZ
#   20/CD
#   villas/NNS
#   replete/JJ
#   with/IN
#   white/JJ
#   marble/JJ
#   pillars/NNS
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   a/DT
#   (GPE Chinese/JJ)
#   pavilion/NN
#   ./.
#   Once/IN
#   the/DT
#   headquarters/NN
#   of/IN
#   the/DT
#   firm/NN
#   ,/,
#   today/NN
#   all/DT
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   signs/NNS
#   have/VBP
#   been/VBN
#   stripped/VBN
#   from/IN
#   the/DT
#   gate/NN
#   ./.
#   A/DT
#   (ORGANIZATION CEFC/NNP)
#   charity/NN
#   is/VBZ
#   located/VBN
#   100/CD
#   meters/NNS
#   away/RB
#   from/IN
#   the/DT
#   (ORGANIZATION CEFC/NNP)
#   HQ/NNP
#   compound/NN
#   ./.
#   This/DT
#   notice/NN
#   says/VBZ
#   the/DT
#   power/NN
#   supply/NN
#   is/VBZ
#   to/TO
#   be/VB
#   cut/VBN
#   owing/VBG
#   from/IN
#   November/NNP
#   28/CD
#   due/JJ
#   to/TO
#   overdue/JJ
#   bills/NNS
#   ./.
#   CNN/VB
#   A/DT
#   sketch/NN
#   of/IN
#   the/DT
#   building/NN
#   from/IN
#   (ORGANIZATION CEFC/NNP)
#   ’/NNP
#   s/VBD
#   website/RB
#   ./.
#   CEFC/VB
#   The/DT
#   side/NN
#   gate/NN
#   of/IN
#   the/DT
#   (ORGANIZATION CEFC/NNP)
#   compound/NN
#   in/IN
#   November/NNP
#   2018/CD
#   ./.
#   (ORGANIZATION CNN/NNP Ye/NNP)
#   relocated/VBD
#   to/TO
#   (GPE Shanghai/NNP)
#   from/IN
#   (GPE Fujian/NNP)
#   around/IN
#   2009/CD
#   ,/,
#   according/VBG
#   to/TO
#   records/NNS
#   seen/VBN
#   by/IN
#   (GPE Chinese/JJ)
#   financial/JJ
#   news/NN
#   outlet/NN
#   (PERSON Caixin/NNP)
#   ./.
#   ``/``
#   He/PRP
#   was/VBD
#   part/NN
#   of/IN
#   a/DT
#   (GPE Fujian/JJ)
#   clique/NN
#   that/IN
#   all/DT
#   rose/VBD
#   together/RB
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Chubb/NNP)
#   ,/,
#   whose/WP$
#   blog/NN
#   ,/,
#   (GPE South/NNP)
#   Sea/NNP
#   Conversations/NNP
#   ,/,
#   has/VBZ
#   closely/RB
#   tracked/VBN
#   the/DT
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   story/NN
#   ./.
#   The/DT
#   group/NN
#   emerged/VBD
#   while/IN
#   (PERSON Xi/NNP Jinping/NNP)
#   was/VBD
#   still/RB
#   in/IN
#   the/DT
#   (GPE Fujian/JJ)
#   government/NN
#   ./.
#   It/PRP
#   moved/VBD
#   to/TO
#   (GPE Shanghai/NNP)
#   around/IN
#   the/DT
#   same/JJ
#   time/NN
#   as/IN
#   (PERSON Xi/NN)
#   did/VBD
#   --/:
#   although/IN
#   it/PRP
#   is/VBZ
#   unclear/JJ
#   whether/IN
#   or/CC
#   not/RB
#   their/PRP$
#   lives/NNS
#   intersected/VBN
#   ./.
#   It/PRP
#   was/VBD
#   in/IN
#   (GPE Shanghai/NNP)
#   that/IN
#   (PERSON Ye/NNP)
#   's/POS
#   business/NN
#   empire/NN
#   mushroomed/VBD
#   ./.
#   He/PRP
#   became/VBD
#   the/DT
#   epicenter/NN
#   of/IN
#   a/DT
#   multi-billion-dollar/JJ
#   constellation/NN
#   of/IN
#   companies/NNS
#   based/VBN
#   in/IN
#   the/DT
#   (ORGANIZATION Czech/NNP Republic/NNP)
#   ,/,
#   (GPE Singapore/NNP)
#   ,/,
#   (GPE Hong/NNP Kong/NNP)
#   ,/,
#   (PERSON Bermuda/NNP)
#   and/CC
#   mainland/VB
#   (GPE China/NNP)
#   ./.
#   In/IN
#   2011/CD
#   ,/,
#   his/PRP$
#   company/NN
#   's/POS
#   (ORGANIZATION NGO/NNP)
#   ,/,
#   the/DT
#   (GPE China/NNP)
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   ,/,
#   was/VBD
#   awarded/VBN
#   consultative/JJ
#   status/NN
#   at/IN
#   the/DT
#   (ORGANIZATION UN/NNP)
#   ./.
#   It/PRP
#   was/VBD
#   a/DT
#   highly/RB
#   unusual/JJ
#   ,/,
#   if/IN
#   not/RB
#   unprecedented/VBN
#   ,/,
#   move/VB
#   for/IN
#   a/DT
#   private/JJ
#   energy/NN
#   company/NN
#   ./.
#   Why/WRB
#   a/DT
#   (GPE Chinese/JJ)
#   energy/NN
#   company/NN
#   would/MD
#   fund/VB
#   an/DT
#   NGO/NNP
#   at/IN
#   the/DT
#   (ORGANIZATION UN/NNP)
#   puzzled/VBD
#   (PERSON Glaser/NNP)
#   ,/,
#   the/DT
#   (ORGANIZATION US/NNP)
#   academic/VB
#   who/WP
#   had/VBD
#   met/VBN
#   (PERSON Ye/NNP)
#   ./.
#   Officially/RB
#   ,/,
#   its/PRP$
#   mission/NN
#   was/VBD
#   to/TO
#   serve/VB
#   as/IN
#   ``/``
#   a/DT
#   high-end/JJ
#   strategic/JJ
#   think/NN
#   tank/NN
#   ''/''
#   on/IN
#   energy/NN
#   ./.
#   Much/JJ
#   of/IN
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   ’/NNP
#   s/VBD
#   time/NN
#   was/VBD
#   spent/VBN
#   holding/VBG
#   conferences/NNS
#   on/IN
#   the/DT
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (GPE Road/NNP)
#   initiative/NN
#   ./.
#   The/DT
#   events/NNS
#   were/VBD
#   surreal/JJ
#   for/IN
#   being/VBG
#   so/RB
#   ``/``
#   pro-China/JJ
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Glaser/NNP)
#   ./.
#   Still/RB
#   ,/,
#   they/PRP
#   attracted/VBD
#   an/DT
#   impressive/JJ
#   crowd/NN
#   ./.
#   A/DT
#   former/JJ
#   head/NN
#   of/IN
#   an/DT
#   oil/NN
#   conglomerate/NN
#   ,/,
#   (GSP US/NNP)
#   and/CC
#   (GPE Russian/JJ)
#   ex-diplomats/NNS
#   ,/,
#   and/CC
#   retirees/NNS
#   of/IN
#   (GPE America/NNP)
#   's/POS
#   (ORGANIZATION National/NNP)
#   Security/NNP
#   Agency/NNP
#   and/CC
#   the/DT
#   (ORGANIZATION CIA/NNP)
#   all/DT
#   appeared/VBD
#   at/IN
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   ’/NNP
#   s/JJ
#   events/NNS
#   ./.
#   “/NN
#   I/PRP
#   did/VBD
#   n't/RB
#   have/VB
#   a/DT
#   clear/JJ
#   idea/NN
#   ,/,
#   and/CC
#   for/IN
#   that/DT
#   matter/NN
#   still/RB
#   do/VBP
#   n't/RB
#   ,/,
#   what/WP
#   the/DT
#   (GPE China/NNP)
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   ”/NNP
#   Hugh/NNP
#   White/NNP
#   ,/,
#   professor/NN
#   of/IN
#   strategic/JJ
#   studies/NNS
#   at/IN
#   the/DT
#   (ORGANIZATION Australian/JJ National/NNP University/NNP)
#   ,/,
#   in/IN
#   (GPE Canberra/NNP)
#   ``/``
#   I/PRP
#   remember/VBP
#   .../:
#   thinking/NN
#   ,/,
#   wow/NN
#   ,/,
#   they/PRP
#   're/VBP
#   bringing/VBG
#   in/IN
#   really/RB
#   senior/JJ
#   people/NNS
#   now/RB
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Glaser/NNP)
#   ./.
#   But/CC
#   many/JJ
#   scholars/NNS
#   who/WP
#   attended/VBD
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   ’/NNP
#   s/NN
#   forums/NNS
#   had/VBD
#   never/RB
#   heard/VBN
#   of/IN
#   (GPE Ye/NNP)
#   ./.
#   They/PRP
#   assumed/VBD
#   the/DT
#   (GPE China/NNP)
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   a/DT
#   vessel/NN
#   of/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ,/,
#   says/VBZ
#   (PERSON Hugh/NNP White/NNP)
#   ,/,
#   of/IN
#   the/DT
#   (GPE Australian/NNP)
#   (ORGANIZATION National/NNP University/NNP)
#   ,/,
#   who/WP
#   took/VBD
#   part/NN
#   in/IN
#   one/CD
#   such/JJ
#   event/NN
#   in/IN
#   2015/CD
#   ./.
#   He/PRP
#   pauses/VBZ
#   before/IN
#   adding/VBG
#   :/:
#   ``/``
#   But/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   have/VB
#   a/DT
#   clear/JJ
#   idea/NN
#   ,/,
#   and/CC
#   for/IN
#   that/DT
#   matter/NN
#   still/RB
#   do/VBP
#   n't/RB
#   ,/,
#   what/WP
#   the/DT
#   (GPE China/NNP)
#   Energy/NNP
#   Fund/NNP
#   Committee/NNP
#   was/VBD
#   ''/''
#   At/IN
#   the/DT
#   (ORGANIZATION UN/NNP)
#   ,/,
#   employees/NNS
#   of/IN
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/NN
#   (ORGANIZATION NGO/NNP)
#   were/VBD
#   rubbing/VBG
#   shoulders/NNS
#   with/IN
#   some/DT
#   of/IN
#   the/DT
#   most/RBS
#   important/JJ
#   men/NNS
#   in/IN
#   the/DT
#   world/NN
#   ./.
#   In/IN
#   the/DT
#   four/CD
#   years/NNS
#   after/IN
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   arrived/VBD
#   in/IN
#   (GPE New/NNP York/NNP)
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   's/POS
#   revenue/NN
#   grew/VBD
#   by/IN
#   25/CD
#   %/NN
#   annually/RB
#   ,/,
#   according/VBG
#   to/TO
#   the/DT
#   company/NN
#   's/POS
#   website/NN
#   ./.
#   As/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   thrived/VBD
#   ,/,
#   (PERSON Ye/NNP)
#   traveled/VBD
#   the/DT
#   world/NN
#   on/IN
#   his/PRP$
#   private/JJ
#   (ORGANIZATION Airbus/NNP)
#   glad-handing/NN
#   leaders/NNS
#   ,/,
#   including/VBG
#   President/NNP
#   (PERSON Erdogan/NNP)
#   of/IN
#   (GPE Turkey/NNP)
#   ,/,
#   the/DT
#   former/JJ
#   (ORGANIZATION US/NNP)
#   secretary/NN
#   of/IN
#   state/NN
#   (PERSON Henry/NNP Kissinger/NNP)
#   ,/,
#   the/DT
#   prime/JJ
#   minister/NN
#   of/IN
#   (GPE Kazakhstan/NNP)
#   ,/,
#   and/CC
#   (PERSON Alan/NNP Greenspan/NNP)
#   ,/,
#   the/DT
#   former/JJ
#   (ORGANIZATION US/NNP)
#   Federal/NNP
#   Reserve/NNP
#   chairman/NN
#   ./.
#   With/IN
#   better/JJR
#   political/JJ
#   connections/NNS
#   came/VBD
#   bigger/JJR
#   international/JJ
#   deals/NNS
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   for/IN
#   example/NN
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   established/VBD
#   trade/NN
#   deals/NNS
#   in/IN
#   (GPE Georgia/NNP)
#   and/CC
#   reached/VBD
#   a/DT
#   $/$
#   680/CD
#   million/CD
#   agreement/NN
#   --/:
#   which/WDT
#   has/VBZ
#   since/IN
#   fallen/VBN
#   through/IN
#   --/:
#   with/IN
#   a/DT
#   (GPE Kazakh/NNP)
#   state/NN
#   oil/NN
#   and/CC
#   gas/NN
#   firm/NN
#   ./.
#   The/DT
#   next/JJ
#   year/NN
#   ,/,
#   it/PRP
#   spent/VBD
#   $/$
#   900/CD
#   million/CD
#   on/IN
#   a/DT
#   stake/NN
#   in/IN
#   a/DT
#   huge/JJ
#   oil/NN
#   field/NN
#   majority-owned/JJ
#   by/IN
#   (PERSON Abu/NNP Dhabi/NNP National/NNP Oil/NNP Co/NNP)
#   ./.
#   In/IN
#   its/PRP$
#   press/NN
#   releases/NNS
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   billed/VBD
#   many/JJ
#   of/IN
#   these/DT
#   ventures/NNS
#   as/IN
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (ORGANIZATION Road/NNP)
#   deals/NNS
#   ,/,
#   further/RB
#   aligning/VBG
#   itself/PRP
#   with/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ./.
#   ``/``
#   There/EX
#   is/VBZ
#   no/DT
#   type/NN
#   of/IN
#   project/NN
#   that/WDT
#   does/VBZ
#   n't/RB
#   qualify/VB
#   as/IN
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (PERSON Road/NNP)
#   ,/,
#   and/CC
#   no/DT
#   continent/NN
#   on/IN
#   the/DT
#   planet/NN
#   that/WDT
#   does/VBZ
#   n't/RB
#   have/VB
#   (PERSON Belt/NNP)
#   and/CC
#   (PERSON Road/NNP)
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Christopher/NNP Balding/NNP)
#   ,/,
#   an/DT
#   associate/NN
#   professor/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Fulbright/NNP University/NNP Vietnam/NNP)
#   ./.
#   (PERSON Due/NNP)
#   to/TO
#   tight/VB
#   capital/NN
#   controls/NNS
#   ,/,
#   (GPE Chinese/JJ)
#   companies/NNS
#   struggle/VBP
#   to/TO
#   move/VB
#   money/NN
#   abroad/RB
#   ,/,
#   he/PRP
#   explains/VBZ
#   ./.
#   Calling/VBG
#   deals/NNS
#   “/NNP
#   Belt/NNP
#   and/CC
#   (PERSON Road/NNP)
#   ”/NNP
#   projects/NNS
#   helps/VBP
#   companies/NNS
#   gain/VBP
#   the/DT
#   support/NN
#   of/IN
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   to/TO
#   do/VB
#   business/NN
#   internationally/RB
#   and/CC
#   move/VB
#   money/NN
#   out/IN
#   of/IN
#   (GPE China/NNP)
#   ,/,
#   adds/VBZ
#   Balding/NNP
#   ./.
#   “/NN
#   There/EX
#   is/VBZ
#   no/DT
#   type/NN
#   of/IN
#   project/NN
#   that/WDT
#   does/VBZ
#   n't/RB
#   qualify/VB
#   as/IN
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (PERSON Road/NNP)
#   ,/,
#   and/CC
#   no/DT
#   continent/NN
#   on/IN
#   the/DT
#   planet/NN
#   that/WDT
#   does/VBZ
#   n't/RB
#   have/VB
#   (PERSON Belt/NNP)
#   and/CC
#   (PERSON Road/NNP)
#   ”/NNP
#   Christopher/NNP
#   Balding/NNP
#   ,/,
#   an/DT
#   associate/NN
#   professor/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Fulbright/NNP University/NNP Vietnam/NNP)
#   In/IN
#   September/NNP
#   2017/CD
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   announced/VBD
#   its/PRP$
#   most/RBS
#   high-profile/JJ
#   investment/NN
#   yet/RB
#   ./.
#   The/DT
#   company/NN
#   was/VBD
#   to/TO
#   buy/VB
#   a/DT
#   14/CD
#   %/NN
#   stake/NN
#   in/IN
#   (GPE Russian/JJ)
#   oil/NN
#   giant/NN
#   (PERSON Rosneft/NNP)
#   for/IN
#   $/$
#   9/CD
#   billion/CD
#   --/:
#   the/DT
#   sort/NN
#   of/IN
#   super/JJ
#   spend/NN
#   usually/RB
#   reserved/VBN
#   for/IN
#   a/DT
#   state-owned/JJ
#   company/NN
#   ./.
#   That/DT
#   raised/VBD
#   eyebrows/NNS
#   ,/,
#   says/VBZ
#   (PERSON Laban/NNP Yu/NNP)
#   ,/,
#   at/IN
#   the/DT
#   (ORGANIZATION Jefferies/NNP Group/NNP)
#   investment/NN
#   bank/NN
#   ./.
#   ``/``
#   I/PRP
#   thought/VBD
#   ,/,
#   who/WP
#   would/MD
#   give/VB
#   them/PRP
#   that/DT
#   kind/NN
#   of/IN
#   money/NN
#   ?/.
#   ''/''
#   The/DT
#   empire/NN
#   falls/VBZ
#   (PERSON Film/NNP)
#   star/NN
#   (PERSON Jackie/NNP Chan/NNP)
#   (/(
#   left/VBN
#   )/)
#   and/CC
#   the/DT
#   then/RB
#   (GPE Hong/NNP Kong/NNP)
#   Home/NNP
#   Affairs/NNP
#   secretary/NN
#   (PERSON Patrick/NNP Ho/NNP)
#   at/IN
#   an/DT
#   event/NN
#   raising/VBG
#   money/NN
#   for/IN
#   the/DT
#   (ORGANIZATION Jackie/NNP)
#   Chan/NNP
#   Charitable/NNP
#   foundation/NN
#   ,/,
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNPS Children/NNP)
#   's/POS
#   Fund/NN
#   and/CC
#   the/DT
#   (ORGANIZATION Community/NNP Chest/NNP)
#   ./.
#   (PERSON Samantha/NNP)
#   Sin/AFP/Getty/NNP
#   (PERSON Images/NNP Ye/NNP)
#   ’/NNP
#   s/VBD
#   empire/NN
#   began/VBD
#   to/TO
#   crumble/VB
#   on/IN
#   November/NNP
#   18/CD
#   ,/,
#   2017/CD
#   ./.
#   On/IN
#   that/DT
#   day/NN
#   ,/,
#   (ORGANIZATION FBI/NNP)
#   agents/NNS
#   arrested/VBD
#   (PERSON Patrick/NNP Ho/NNP)
#   Chi-ping/NNP
#   ,/,
#   the/DT
#   man/NN
#   (PERSON Ye/NNP)
#   had/VBD
#   employed/VBN
#   to/TO
#   lead/VB
#   his/PRP$
#   (ORGANIZATION NGO/NNP)
#   ./.
#   (PERSON Ho/NNP)
#   was/VBD
#   charged/VBN
#   with/IN
#   money/NN
#   laundering/NN
#   and/CC
#   violating/VBG
#   the/DT
#   (ORGANIZATION Foreign/NNP Corrupt/NNP)
#   Practices/NNP
#   Act/NNP
#   ./.
#   He/PRP
#   is/VBZ
#   accused/VBN
#   of/IN
#   offering/VBG
#   $/$
#   3/CD
#   million/CD
#   in/IN
#   bribes/NNS
#   to/TO
#   the/DT
#   President/NNP
#   of/IN
#   (GPE Chad/NNP)
#   ,/,
#   (PERSON Idriss/NNP Deby/NNP)
#   ,/,
#   and/CC
#   (PERSON Sam/NNP Kutesa/NNP)
#   ,/,
#   the/DT
#   Ugandan/NNP
#   minister/NN
#   of/IN
#   foreign/JJ
#   affairs/NNS
#   and/CC
#   then/RB
#   president/NN
#   of/IN
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNP)
#   General/NNP
#   Assembly/NNP
#   ./.
#   The/DT
#   alleged/JJ
#   bribes/NNS
#   were/VBD
#   made/VBN
#   on/IN
#   behalf/NN
#   of/IN
#   a/DT
#   Shanghai-based/JJ
#   energy/NN
#   company/NN
#   ,/,
#   which/WDT
#   is/VBZ
#   not/RB
#   explicitly/RB
#   named/VBN
#   in/IN
#   the/DT
#   court/NN
#   documents/NNS
#   ./.
#   (ORGANIZATION CNN/NNP)
#   emails/NNS
#   and/CC
#   calls/VBZ
#   to/TO
#   the/DT
#   government/NN
#   of/IN
#   (PERSON Chad/NNP)
#   went/VBD
#   unanswered/JJ
#   ./.
#   Last/JJ
#   year/NN
#   ,/,
#   the/DT
#   government/NN
#   of/IN
#   (PERSON Chad/NNP)
#   said/VBD
#   in/IN
#   a/DT
#   statement/NN
#   :/:
#   ``/``
#   Faced/VBD
#   with/IN
#   this/DT
#   umpteenth/JJ
#   false/JJ
#   allegation/NN
#   ,/,
#   the/DT
#   government/NN
#   of/IN
#   (PERSON Chad/NNP)
#   formally/RB
#   refutes/VBZ
#   this/DT
#   shameful/JJ
#   fabrication/NN
#   ./.
#   ''/''
#   The/DT
#   government/NN
#   of/IN
#   (GSP Uganda/NNP)
#   has/VBZ
#   said/VBD
#   in/IN
#   a/DT
#   statement/NN
#   that/IN
#   it/PRP
#   was/VBD
#   ``/``
#   erroneous/JJ
#   ''/''
#   to/TO
#   say/VB
#   (PERSON Kutesa/NNP)
#   was/VBD
#   involved/VBN
#   with/IN
#   the/DT
#   alleged/VBN
#   bribery/NN
#   ./.
#   Ho/NNP
#   ’/NNP
#   s/VBD
#   lawyer/NN
#   declined/VBD
#   to/TO
#   comment/VB
#   ,/,
#   but/CC
#   his/PRP$
#   client/NN
#   has/VBZ
#   pleaded/VBN
#   not/RB
#   guilty/JJ
#   to/TO
#   the/DT
#   charges/NNS
#   against/IN
#   him/PRP
#   ./.
#   At/IN
#   times/NNS
#   ,/,
#   court/NN
#   documents/NNS
#   show/VBP
#   ,/,
#   some/DT
#   people/NNS
#   at/IN
#   the/DT
#   (ORGANIZATION UN/NNP)
#   treated/VBD
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   as/IN
#   an/DT
#   arm/NN
#   of/IN
#   the/DT
#   (GPE Chinese/JJ)
#   state/NN
#   ./.
#   For/IN
#   example/NN
#   ,/,
#   according/VBG
#   to/TO
#   emails/NNS
#   presented/VBN
#   by/IN
#   prosecutors/NNS
#   ,/,
#   (PERSON Ho/NNP)
#   was/VBD
#   asked/VBN
#   by/IN
#   an/DT
#   associate/NN
#   to/TO
#   ``/``
#   intervene/VB
#   with/IN
#   the/DT
#   (GPE Chinese/JJ)
#   state/NN
#   ''/''
#   to/TO
#   provide/VB
#   (PERSON Chad/NNP)
#   with/IN
#   military/JJ
#   weapons/NNS
#   to/TO
#   fight/VB
#   (PERSON Boko/NNP Haram/NNP)
#   ./.
#   In/IN
#   emails/NNS
#   with/IN
#   other/JJ
#   individuals/NNS
#   ,/,
#   (PERSON Ho/NNP)
#   also/RB
#   discusses/VBZ
#   passing/VBG
#   on/IN
#   arms/NNS
#   to/TO
#   (GPE Libya/NNP)
#   and/CC
#   (PERSON Qatar/NNP)
#   and/CC
#   suggests/VBZ
#   that/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   could/MD
#   help/VB
#   an/DT
#   (GPE Iranian/JJ)
#   company/NN
#   move/NN
#   sanctioned/VBD
#   money/NN
#   out/IN
#   of/IN
#   (GPE China/NNP)
#   ,/,
#   according/VBG
#   to/TO
#   prosecutors/NNS
#   ./.
#   In/IN
#   a/DT
#   statement/NN
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   distanced/VBD
#   itself/PRP
#   from/IN
#   the/DT
#   (ORGANIZATION NGO/NNP)
#   ,/,
#   saying/VBG
#   that/IN
#   the/DT
#   latter/NN
#   was/VBD
#   ``/``
#   not/RB
#   involved/VBN
#   in/IN
#   any/DT
#   of/IN
#   the/DT
#   commercial/JJ
#   activities/NNS
#   of/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ./.
#   ''/''
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   said/VBD
#   it/PRP
#   conducted/VBD
#   its/PRP$
#   business/NN
#   activities/NNS
#   ``/``
#   in/IN
#   strict/JJ
#   accordance/NN
#   with/IN
#   the/DT
#   law/NN
#   ./.
#   ''/''
#   A/DT
#   house/NN
#   of/IN
#   cards/NNS
#   In/IN
#   the/DT
#   end/NN
#   ,/,
#   no/DT
#   one/NN
#   gave/VBD
#   (ORGANIZATION CEFC/NNP China/NNP)
#   Energy/NNP
#   the/DT
#   $/$
#   9/CD
#   billion/CD
#   to/TO
#   buy/VB
#   the/DT
#   stake/NN
#   in/IN
#   (GPE Rosneft/NNP)
#   ./.
#   Two/CD
#   months/NNS
#   after/IN
#   the/DT
#   deal/NN
#   was/VBD
#   announced/VBN
#   ,/,
#   (PERSON Ho/NNP)
#   was/VBD
#   arrested/VBN
#   ./.
#   It/PRP
#   was/VBD
#   the/DT
#   falling/VBG
#   domino/NN
#   that/WDT
#   would/MD
#   bring/VB
#   down/RP
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/NN
#   empire/NN
#   ./.
#   On/IN
#   March/NNP
#   1/CD
#   this/DT
#   year/NN
#   ,/,
#   respected/VBD
#   (GPE Chinese/JJ)
#   financial/JJ
#   news/NN
#   outlet/NN
#   ,/,
#   (GPE Caixin/NNP)
#   ,/,
#   published/VBD
#   an/DT
#   explosive/JJ
#   forensic/JJ
#   investigation/NN
#   into/IN
#   the/DT
#   finances/NNS
#   of/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ,/,
#   alleging/VBG
#   that/IN
#   the/DT
#   organization/NN
#   was/VBD
#   a/DT
#   house/NN
#   of/IN
#   cards/NNS
#   ,/,
#   precariously/RB
#   stacked/VBN
#   on/IN
#   loans/NNS
#   to/TO
#   cover/VB
#   loans/NNS
#   ./.
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   said/VBD
#   the/DT
#   report/NN
#   ``/``
#   had/VBD
#   no/DT
#   basis/NN
#   in/IN
#   fact/NN
#   ./.
#   ''/''
#   Days/VBZ
#   later/RB
#   ,/,
#   (PERSON Ye/NNP)
#   was/VBD
#   reportedly/RB
#   detained/VBN
#   in/IN
#   (GPE China/NNP)
#   --/:
#   and/CC
#   he/PRP
#   has/VBZ
#   not/RB
#   been/VBN
#   seen/VBN
#   since/IN
#   ./.
#   Industry/NN
#   analysts/NNS
#   say/VBP
#   there/EX
#   had/VBD
#   long/RB
#   been/VBN
#   whispers/NNS
#   about/IN
#   the/DT
#   stability/NN
#   of/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ,/,
#   with/IN
#   experts/NNS
#   believing/VBG
#   the/DT
#   company/NN
#   did/VBD
#   not/RB
#   have/VB
#   enough/RB
#   business/NN
#   to/TO
#   match/VB
#   its/PRP$
#   size/NN
#   ./.
#   The/DT
#   entire/JJ
#   floor/NN
#   where/WRB
#   one/CD
#   (ORGANIZATION CEFC/NNP)
#   branch/NN
#   is/VBZ
#   registered/VBN
#   at/IN
#   is/VBZ
#   empty/JJ
#   ./.
#   The/DT
#   management/NN
#   said/VBD
#   it/PRP
#   had/VBD
#   never/RB
#   been/VBN
#   occupied/VBN
#   ./.
#   (ORGANIZATION CNN/NNP)
#   One/NNP
#   address/NN
#   of/IN
#   three/CD
#   registered/VBD
#   (ORGANIZATION CEFC/NNP)
#   related/JJ
#   companies/NNS
#   is/VBZ
#   a/DT
#   defunct/JJ
#   office/NN
#   ./.
#   (ORGANIZATION CNN/NNP)
#   ``/``
#   Accounting/NNP
#   standards/NNS
#   and/CC
#   corporate/JJ
#   oversight/NN
#   is/VBZ
#   still/RB
#   pretty/JJ
#   weak/JJ
#   in/IN
#   (GPE China/NNP)
#   and/CC
#   there/EX
#   is/VBZ
#   n't/RB
#   a/DT
#   lot/NN
#   of/IN
#   transparency/NN
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Tom/NNP Rafferty/NNP)
#   ,/,
#   a/DT
#   (GPE China/NNP)
#   expert/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Economist/NNP Intelligence/NNP Unit/NNP)
#   ./.
#   ``/``
#   There/EX
#   are/VBP
#   lots/NNS
#   of/IN
#   issues/NNS
#   in/IN
#   (GPE China/NNP)
#   around/IN
#   opaque/JJ
#   corporate/JJ
#   structures/NNS
#   ./.
#   ''/''
#   (ORGANIZATION CNN/NNP)
#   contacted/VBD
#   (GPE China/NNP)
#   ’/NNP
#   s/VBD
#   (ORGANIZATION Ministry/NNP)
#   of/IN
#   (ORGANIZATION Foreign/NNP Affairs/NNPS)
#   about/IN
#   the/DT
#   relationship/NN
#   between/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   and/CC
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   ,/,
#   (PERSON Ho/NNP)
#   ’/NNP
#   s/NN
#   arrest/NN
#   in/IN
#   (GPE New/NNP York/NNP)
#   and/CC
#   the/DT
#   reports/NNS
#   that/IN
#   (PERSON Ye/NNP)
#   has/VBZ
#   been/VBN
#   detained/VBN
#   by/IN
#   the/DT
#   (GPE Chinese/JJ)
#   authorities/NNS
#   ./.
#   A/DT
#   spokesperson/NN
#   faxed/VBD
#   back/RP
#   the/DT
#   following/JJ
#   response/NN
#   :/:
#   “/NN
#   I/PRP
#   have/VBP
#   no/DT
#   knowledge/NN
#   about/IN
#   the/DT
#   incident/NN
#   you/PRP
#   mentioned/VBD
#   ./.
#   What/WP
#   I/PRP
#   can/MD
#   tell/VB
#   you/PRP
#   is/VBZ
#   ,/,
#   (GPE China/NNP)
#   is/VBZ
#   a/DT
#   country/NN
#   ruled/VBN
#   by/IN
#   law/NN
#   ,/,
#   and/CC
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   has/VBZ
#   consistently/RB
#   asked/VBN
#   (GPE Chinese/JJ)
#   enterprises/NNS
#   to/TO
#   abide/VB
#   by/IN
#   local/JJ
#   law/NN
#   and/CC
#   regulations/NNS
#   when/WRB
#   they/PRP
#   operate/VBP
#   overseas./JJ
#   ”/NN
#   Attempts/NNP
#   to/TO
#   reach/VB
#   Ye/NNP
#   for/IN
#   comment/NN
#   through/IN
#   his/PRP$
#   company/NN
#   were/VBD
#   unsuccessful/JJ
#   ./.
#   In/IN
#   (GPE Shanghai/NNP)
#   ,/,
#   (ORGANIZATION CNN/NNP)
#   visited/VBD
#   the/DT
#   registered/JJ
#   addresses/NNS
#   of/IN
#   eight/CD
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   subsidiary/NN
#   companies/NNS
#   ./.
#   (PERSON None/NN)
#   showed/VBD
#   any/DT
#   sign/NN
#   of/IN
#   the/DT
#   company/NN
#   ./.
#   Two/CD
#   locations/NNS
#   were/VBD
#   new/JJ
#   office/NN
#   buildings/NNS
#   which/WDT
#   had/VBD
#   never/RB
#   been/VBN
#   rented/VBN
#   out/RP
#   ,/,
#   while/IN
#   one/CD
#   was/VBD
#   a/DT
#   state-owned/JJ
#   bank/NN
#   ./.
#   At/IN
#   one/CD
#   near-empty/JJ
#   building/NN
#   ,/,
#   a/DT
#   sign/NN
#   carried/VBD
#   a/DT
#   President/NNP
#   Xi/NNP
#   quote/NN
#   :/:
#   ``/``
#   (GPE China/NNP)
#   's/POS
#   door/NN
#   to/TO
#   the/DT
#   world/NN
#   will/MD
#   never/RB
#   close/VB
#   ,/,
#   but/CC
#   only/RB
#   open/JJ
#   wider/NN
#   ./.
#   ''/''
#   (ORGANIZATION CEFC/NNP)
#   is/VBZ
#   finally/RB
#   state-owned/JJ
#   Once/IN
#   a/DT
#   big/JJ
#   buyer/NN
#   ,/,
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   is/VBZ
#   now/RB
#   a/DT
#   big/JJ
#   seller/NN
#   --/:
#   its/PRP$
#   property/NN
#   is/VBZ
#   under/IN
#   the/DT
#   hammer/NN
#   ,/,
#   with/IN
#   a/DT
#   (GPE Chinese/JJ)
#   state-owned/JJ
#   company/NN
#   taking/VBG
#   control/NN
#   of/IN
#   many/JJ
#   of/IN
#   its/PRP$
#   international/JJ
#   assets/NNS
#   ./.
#   (PERSON Ye/NNP)
#   ’/NNP
#   s/VBD
#   former/JJ
#   (ORGANIZATION Bel/NNP Air/NNP)
#   mansion/NN
#   in/IN
#   (GPE Pok/NNP)
#   Fu/NNP
#   Lam/NNP
#   ,/,
#   (GPE Hong/NNP Kong/NNP)
#   ./.
#   (PERSON Savills/NNP Ye/NNP Jianming/NNP)
#   bought/VBD
#   a/DT
#   two-bedroom/JJ
#   apartment/NN
#   overlooking/VBG
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNPS)
#   ./.
#   (ORGANIZATION Newscom/NNP)
#   In/IN
#   (GPE March/NNP)
#   ,/,
#   the/DT
#   (GPE Czech/JJ)
#   government/NN
#   sent/VBD
#   a/DT
#   delegation/NN
#   to/TO
#   (GPE Beijing/NNP)
#   to/TO
#   find/VB
#   out/RP
#   where/WRB
#   (PERSON Ye/NNP)
#   had/VBD
#   gone/VBN
#   ./.
#   (PERSON Czech/NNP)
#   President/NNP
#   (PERSON Zeman/NNP)
#   said/VBD
#   that/IN
#   (PERSON Ye/NNP)
#   ,/,
#   who/WP
#   is/VBZ
#   still/RB
#   his/PRP$
#   economic/JJ
#   adviser/NN
#   ,/,
#   was/VBD
#   being/VBG
#   investigated/VBN
#   in/IN
#   (GPE China/NNP)
#   on/IN
#   ``/``
#   suspicion/NN
#   of/IN
#   breaking/VBG
#   the/DT
#   law/NN
#   ./.
#   ''/''
#   (PERSON Zeman/NNP)
#   ’/NNP
#   s/VBD
#   spokesman/NN
#   tells/NNS
#   (ORGANIZATION CNN/NNP)
#   that/IN
#   if/IN
#   (PERSON Ye/NNP)
#   “/NNP
#   is/VBZ
#   found/VBN
#   guilty/JJ
#   he/PRP
#   will/MD
#   cease/VB
#   to/TO
#   be/VB
#   an/DT
#   adviser/NN
#   to/TO
#   (PERSON Zeman/NNP)
#   ./.
#   ''/''
#   (PERSON Ye/NNP)
#   's/POS
#   downfall/NN
#   comes/VBZ
#   amid/IN
#   a/DT
#   wider/NN
#   crackdown/NN
#   in/IN
#   (GPE China/NNP)
#   on/IN
#   debt-ridden/JJ
#   private/JJ
#   companies/NNS
#   ./.
#   Earlier/RBR
#   this/DT
#   year/NN
#   ,/,
#   (PERSON Wu/NNP Xiaohui/NNP)
#   ,/,
#   chairman/NN
#   of/IN
#   (PERSON Anbang/NNP Insurance/NNP Group/NNP)
#   ,/,
#   which/WDT
#   famously/RB
#   bought/VBD
#   (GPE New/NNP York/NNP)
#   ’/NNP
#   s/JJ
#   (PERSON Waldorf/NNP Hotel/NNP)
#   for/IN
#   $/$
#   1.95/CD
#   billion/CD
#   ,/,
#   was/VBD
#   arrested/VBN
#   for/IN
#   fraudulently/RB
#   raising/VBG
#   billions/NNS
#   of/IN
#   dollars/NNS
#   from/IN
#   investors/NNS
#   ./.
#   In/IN
#   May/NNP
#   ,/,
#   he/PRP
#   was/VBD
#   sentenced/VBN
#   to/TO
#   18/CD
#   years/NNS
#   in/IN
#   jail/NN
#   by/IN
#   a/DT
#   (GPE Shanghai/NNP)
#   court/NN
#   ./.
#   “/VB
#   The/DT
#   government/NN
#   is/VBZ
#   n't/RB
#   happy/JJ
#   about/IN
#   how/WRB
#   they/PRP
#   've/VBP
#   been/VBN
#   conducting/VBG
#   their/PRP$
#   affairs/NNS
#   ,/,
#   particularly/RB
#   if/IN
#   they/PRP
#   've/VBP
#   been/VBN
#   using/VBG
#   it/PRP
#   to/TO
#   move/VB
#   their/PRP$
#   capital/NN
#   out/IN
#   of/IN
#   the/DT
#   country/NN
#   ”/NNP
#   (PERSON Tom/NNP Rafferty/NNP)
#   ,/,
#   principal/JJ
#   economist/NN
#   for/IN
#   (GPE China/NNP)
#   at/IN
#   the/DT
#   (ORGANIZATION Economist/NNP Intelligence/NNP Unit/NNP)
#   ``/``
#   The/DT
#   government/NN
#   is/VBZ
#   n't/RB
#   happy/JJ
#   about/IN
#   how/WRB
#   they/PRP
#   've/VBP
#   been/VBN
#   conducting/VBG
#   their/PRP$
#   affairs/NNS
#   ,/,
#   particularly/RB
#   if/IN
#   they/PRP
#   've/VBP
#   been/VBN
#   using/VBG
#   it/PRP
#   to/TO
#   move/VB
#   their/PRP$
#   capital/NN
#   out/IN
#   of/IN
#   the/DT
#   country/NN
#   ,/,
#   ''/''
#   says/VBZ
#   (PERSON Rafferty/NNP)
#   ,/,
#   of/IN
#   the/DT
#   (ORGANIZATION Economist/NNP Intelligence/NNP Unit/NNP)
#   ,/,
#   regarding/VBG
#   over-leveraged/JJ
#   companies/NNS
#   ./.
#   Two/CD
#   thirds/NNS
#   of/IN
#   the/DT
#   company/NN
#   ’/NNP
#   s/NN
#   financing/NN
#   came/VBD
#   from/IN
#   the/DT
#   state-owned/JJ
#   (GPE China/NNP)
#   Development/NNP
#   Bank/NNP
#   ./.
#   Today/NNP
#   ,/,
#   (GPE Chinese/NNP)
#   state-owned/VBD
#   giant/JJ
#   (ORGANIZATION CITIC/NNP)
#   has/VBZ
#   taken/VBN
#   control/NN
#   of/IN
#   (ORGANIZATION CEFC/NNP China/NNP Energy/NNP)
#   ’/NNP
#   s/VBZ
#   (GPE Czech/NNP)
#   assets/NNS
#   ./.
#   It/PRP
#   's/VBZ
#   an/DT
#   echo/NN
#   of/IN
#   an/DT
#   earlier/JJR
#   (ORGANIZATION Belt/NNP)
#   and/CC
#   (GPE Road/NNP)
#   deal/NN
#   gone/VBN
#   wrong/JJ
#   ,/,
#   in/IN
#   which/WDT
#   the/DT
#   (GPE Chinese/JJ)
#   government/NN
#   took/VBD
#   control/NN
#   of/IN
#   a/DT
#   port/NN
#   in/IN
#   (GPE Sri/NNP)
#   Lanka/NNP
#   when/WRB
#   debts/NNS
#   to/TO
#   a/DT
#   (GPE Chinese/JJ)
#   state-owned/JJ
#   bank/NN
#   could/MD
#   n't/RB
#   be/VB
#   repaid/VBN
#   in/IN
#   2017/CD
#   ./.
#   Meanwhile/RB
#   ,/,
#   the/DT
#   whereabouts/NNS
#   of/IN
#   Ye/NNP
#   are/VBP
#   unknown/JJ
#   --/:
#   and/CC
#   what/WP
#   charges/NNS
#   ,/,
#   if/IN
#   any/DT
#   ,/,
#   he/PRP
#   may/MD
#   face/VB
#   in/IN
#   (GPE China/NNP)
#   have/VBP
#   not/RB
#   been/VBN
#   publicly/RB
#   revealed/VBN
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['Road',
#  'Chinese',
#  'Chinese China',
#  'European',
#  'African',
#  'Manhattan',
#  'Chinese Chinese',
#  'Czech',
#  'European Shanghai',
#  'China',
#  'Chinese China Chinese',
#  'China China',
#  'Beijing',
#  'Prague',
#  'Czech China',
#  'Czech Chinese',
#  'Beijing China',
#  'Europe',
#  'Chinese Road',
#  'Chinese China Europe',
#  'Beijing Chinese',
#  'Beijing American',
#  'Chinese Massachusetts Amherst',
#  'British',
#  'China Chinese',
#  'China China Beijing',
#  'Chinese Ye',
#  'China Hong Kong',
#  'Manhattan China',
#  'China China China',
#  'China Chinese Asia',
#  'Chinese China China',
#  'China Washington',
#  'Shanghai',
#  'English',
#  'Western',
#  'US',
#  'Chinese Fujian',
#  'China Hong Kong Fujian',
#  'Chinese Shanghai',
#  'French',
#  'Chinese Shanghai Fujian',
#  'Chinese Fujian South',
#  'Fujian',
#  'Shanghai Shanghai',
#  'Singapore',
#  'Hong Kong',
#  'China China Chinese',
#  'Road Russian',
#  'America',
#  'China Canberra',
#  'Ye',
#  'China Chinese Australian',
#  'China New York',
#  'Turkey',
#  'Kazakhstan',
#  'Georgia',
#  'Kazakh',
#  'Chinese Chinese Chinese',
#  'China Russian',
#  'Hong Kong Chad',
#  'Chinese Chinese Libya',
#  'Iranian',
#  'China Rosneft',
#  'Chinese Caixin',
#  'China China China China',
#  'China Chinese New York',
#  'Chinese China Chinese Chinese',
#  'Shanghai China',
#  'Chinese Pok',
#  'Hong Kong March',
#  'Czech Beijing',
#  'China China New York',
#  'Shanghai China China',
#  'Chinese Czech',
#  'Road Chinese',
#  'Sri']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['Belt',
#  'CNN Photo',
#  'CEFC China Energy',
#  'Fortune',
#  'United Nations',
#  'Czech Republic',
#  'CEFC China Energy Travel Service',
#  'CEFC China Energy Newscom Inside the Czech Republic',
#  'CEFC China Energy Czech Republic',
#  'Czech Republic Belt',
#  'Czech Republic European Union',
#  'CTK',
#  'AP Images',
#  'University',
#  'Opium Wars',
#  'Jefferies Group',
#  'CEFC China Energy CEFC China Energy',
#  'Trump',
#  'CEFC China Energy Jefferies Group',
#  'Liberation Army',
#  'PLA',
#  'People',
#  'Republic',
#  'SOEs',
#  'State Council',
#  'Communist Party',
#  'PLA International Friendly Contact',
#  'CAIFC',
#  'CEFC China Energy CAIFC',
#  'CAIFC CEFC',
#  'CAIFC Ye',
#  'CEFC China Energy CEFC China Energy Center',
#  'International Studies',
#  'PLA CEFC China Energy',
#  'United Nations NGO',
#  'UN',
#  'PLA Belt',
#  'Concession',
#  'CEFC China Energy CEFC China Energy CEFC',
#  'CEFC',
#  'CEFC CEFC',
#  'CNN Ye',
#  'CEFC China Energy Czech Republic NGO',
#  'UN UN',
#  'US',
#  'NGO',
#  'Belt National',
#  'CIA',
#  'NGO Australian National University',
#  'NGO National University',
#  'UN NGO',
#  'NGO CEFC China Energy',
#  'CEFC China Energy Airbus',
#  'US US',
#  'CEFC China Energy CEFC China Energy Belt',
#  'Road',
#  'Belt Fulbright University Vietnam',
#  'Belt Fulbright University Vietnam CEFC China Energy',
#  'Jefferies Group Jackie',
#  'United Nations Children',
#  'Community Chest',
#  'FBI',
#  'NGO Foreign Corrupt',
#  'United Nations CNN',
#  'UN NGO CEFC China Energy',
#  'CEFC China Energy NGO',
#  'CEFC China Energy CEFC China Energy CEFC China',
#  'CEFC China Energy CEFC China Energy CEFC China Energy',
#  'CEFC CNN',
#  'CEFC CNN Economist Intelligence Unit',
#  'CNN',
#  'Ministry',
#  'Foreign Affairs',
#  'CEFC China Energy CNN',
#  'CEFC China Energy CEFC',
#  'CEFC China Energy Bel Air',
#  'United Nations Newscom',
#  'CNN Economist Intelligence Unit',
#  'Economist Intelligence Unit',
#  'CITIC',
#  'CEFC China Energy Belt']
